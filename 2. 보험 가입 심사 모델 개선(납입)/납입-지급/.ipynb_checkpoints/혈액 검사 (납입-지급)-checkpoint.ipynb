# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('fitted.xlsx')
df.head()
# Out:
#   customer_id   profit review_cat judge  gender  age  insu_req_amount  \
# 0     C112379   585423       혈액검사    재검       1   69           424498
# 1     C112404  -408750       혈액검사    재검       1   69           307520
# 2     C112411  -313680       일반검진    재검       1   69           333680
# 3     C112570  2022721       일반검진    재검       1   67           412210
# 4     C112727  3048120       일반검진    승인       1   65           201880
#
#    insu_pay_amount  insu_duration  insu_cum_amount  ...  new_bt_mchc_judge  \
# 0           724498             11          1320000  ...                NaN
# 1          1008750              5           600000  ...                NaN
# 2           553680              2           240000  ...                NaN
# 3           412210              3           375000  ...                NaN
# 4           201880             26          3250000  ...                NaN
#
#    new_bt_mvc_judge  new_bt_plat_judge  new_bt_rbc_judge  new_bt_wbc_judge  \
# 0               NaN                NaN               NaN               NaN
# 1               NaN                NaN               NaN               NaN
# 2               NaN                NaN               NaN               NaN
# 3               NaN                NaN               NaN               NaN
# 4               NaN                NaN               NaN               NaN
#
#    new_bt_rgpt_judge  new_bt_sgot_judge  new_bt_sgpt_judge  new_bt_trig_judge  \
# 0                1.0                0.0                0.0                NaN
# 1                1.0                0.0                0.0                1.0
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    risk
# 0     0
# 1     1
# 2     1
# 3     0
# 4     0
#
# [5 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4494 entries, 0 to 4493
# Data columns (total 55 columns):
# customer_id              4494 non-null object
# profit                   4494 non-null int64
# review_cat               4494 non-null object
# judge                    4494 non-null object
# gender                   4494 non-null int64
# age                      4494 non-null int64
# insu_req_amount          4494 non-null int64
# insu_pay_amount          4494 non-null int64
# insu_duration            4494 non-null int64
# insu_cum_amount          4494 non-null int64
# height                   4494 non-null int64
# weight                   4494 non-null int64
# bust                     4494 non-null int64
# waist                    4494 non-null int64
# bmi                      4494 non-null float64
# whtr                     4494 non-null float64
# bp_min                   4494 non-null int64
# bp_max                   4494 non-null int64
# pulse_count              4494 non-null int64
# bt_chol                  3509 non-null float64
# bt_crea                  1627 non-null float64
# bt_gluc                  3509 non-null float64
# bt_hb                    2456 non-null float64
# bt_hbsa                  3509 non-null object
# bt_hct                   2456 non-null float64
# bt_mch                   2456 non-null float64
# bt_mchc                  2456 non-null float64
# bt_mvc                   2456 non-null float64
# bt_plat                  2456 non-null float64
# bt_rbc                   2456 non-null float64
# bt_wbc                   2456 non-null float64
# bt_rgpt                  1844 non-null float64
# bt_sgot                  1941 non-null float64
# bt_sgpt                  3509 non-null float64
# bt_trig                  1902 non-null float64
# new_judge_score          4494 non-null int64
# new_bp_judge             4494 non-null int64
# new_pulse_count_judge    4494 non-null int64
# new_bt_chol_judge        3509 non-null float64
# new_bt_crea_judge        1627 non-null float64
# new_bt_gluc_judge        3509 non-null float64
# new_bt_hb_judge          2456 non-null float64
# new_bt_hbsa_judge        3509 non-null float64
# new_bt_hct_judge         2456 non-null float64
# new_bt_mch_judge         2456 non-null float64
# new_bt_mchc_judge        2456 non-null float64
# new_bt_mvc_judge         2456 non-null float64
# new_bt_plat_judge        2456 non-null float64
# new_bt_rbc_judge         2456 non-null float64
# new_bt_wbc_judge         2456 non-null float64
# new_bt_rgpt_judge        1844 non-null float64
# new_bt_sgot_judge        1941 non-null float64
# new_bt_sgpt_judge        3509 non-null float64
# new_bt_trig_judge        1902 non-null float64
# risk                     4494 non-null int64
# dtypes: float64(33), int64(18), object(4)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# customer_id                 0
# profit                      0
# review_cat                  0
# judge                       0
# gender                      0
# age                         0
# insu_req_amount             0
# insu_pay_amount             0
# insu_duration               0
# insu_cum_amount             0
# height                      0
# weight                      0
# bust                        0
# waist                       0
# bmi                         0
# whtr                        0
# bp_min                      0
# bp_max                      0
# pulse_count                 0
# bt_chol                   985
# bt_crea                  2867
# bt_gluc                   985
# bt_hb                    2038
# bt_hbsa                   985
# bt_hct                   2038
# bt_mch                   2038
# bt_mchc                  2038
# bt_mvc                   2038
# bt_plat                  2038
# bt_rbc                   2038
# bt_wbc                   2038
# bt_rgpt                  2650
# bt_sgot                  2553
# bt_sgpt                   985
# bt_trig                  2592
# new_judge_score             0
# new_bp_judge                0
# new_pulse_count_judge       0
# new_bt_chol_judge         985
# new_bt_crea_judge        2867
# new_bt_gluc_judge         985
# new_bt_hb_judge          2038
# new_bt_hbsa_judge         985
# new_bt_hct_judge         2038
# new_bt_mch_judge         2038
# new_bt_mchc_judge        2038
# new_bt_mvc_judge         2038
# new_bt_plat_judge        2038
# new_bt_rbc_judge         2038
# new_bt_wbc_judge         2038
# new_bt_rgpt_judge        2650
# new_bt_sgot_judge        2553
# new_bt_sgpt_judge         985
# new_bt_trig_judge        2592
# risk                        0
# dtype: int64

# %%
# 더 많은 변수를 사용하기 위해서 열을 버리는 것 보다는 많은 변수를 사용해보는 것으로!
# 2470개의 데이터 만들기
df1 = df.dropna(subset=['bt_chol','bt_gluc','bt_hct'])
df1.info()
# bt_crea /
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 8 to 4491
# Data columns (total 55 columns):
# customer_id              2456 non-null object
# profit                   2456 non-null int64
# review_cat               2456 non-null object
# judge                    2456 non-null object
# gender                   2456 non-null int64
# age                      2456 non-null int64
# insu_req_amount          2456 non-null int64
# insu_pay_amount          2456 non-null int64
# insu_duration            2456 non-null int64
# insu_cum_amount          2456 non-null int64
# height                   2456 non-null int64
# weight                   2456 non-null int64
# bust                     2456 non-null int64
# waist                    2456 non-null int64
# bmi                      2456 non-null float64
# whtr                     2456 non-null float64
# bp_min                   2456 non-null int64
# bp_max                   2456 non-null int64
# pulse_count              2456 non-null int64
# bt_chol                  2456 non-null float64
# bt_crea                  1402 non-null float64
# bt_gluc                  2456 non-null float64
# bt_hb                    2456 non-null float64
# bt_hbsa                  2456 non-null object
# bt_hct                   2456 non-null float64
# bt_mch                   2456 non-null float64
# bt_mchc                  2456 non-null float64
# bt_mvc                   2456 non-null float64
# bt_plat                  2456 non-null float64
# bt_rbc                   2456 non-null float64
# bt_wbc                   2456 non-null float64
# bt_rgpt                  882 non-null float64
# bt_sgot                  969 non-null float64
# bt_sgpt                  2456 non-null float64
# bt_trig                  1559 non-null float64
# new_judge_score          2456 non-null int64
# new_bp_judge             2456 non-null int64
# new_pulse_count_judge    2456 non-null int64
# new_bt_chol_judge        2456 non-null float64
# new_bt_crea_judge        1402 non-null float64
# new_bt_gluc_judge        2456 non-null float64
# new_bt_hb_judge          2456 non-null float64
# new_bt_hbsa_judge        2456 non-null float64
# new_bt_hct_judge         2456 non-null float64
# new_bt_mch_judge         2456 non-null float64
# new_bt_mchc_judge        2456 non-null float64
# new_bt_mvc_judge         2456 non-null float64
# new_bt_plat_judge        2456 non-null float64
# new_bt_rbc_judge         2456 non-null float64
# new_bt_wbc_judge         2456 non-null float64
# new_bt_rgpt_judge        882 non-null float64
# new_bt_sgot_judge        969 non-null float64
# new_bt_sgpt_judge        2456 non-null float64
# new_bt_trig_judge        1559 non-null float64
# risk                     2456 non-null int64
# dtypes: float64(33), int64(18), object(4)
# memory usage: 1.0+ MB

# %%
df1.isnull().sum()
# Out:
# customer_id                 0
# profit                      0
# review_cat                  0
# judge                       0
# gender                      0
# age                         0
# insu_req_amount             0
# insu_pay_amount             0
# insu_duration               0
# insu_cum_amount             0
# height                      0
# weight                      0
# bust                        0
# waist                       0
# bmi                         0
# whtr                        0
# bp_min                      0
# bp_max                      0
# pulse_count                 0
# bt_chol                     0
# bt_crea                  1054
# bt_gluc                     0
# bt_hb                       0
# bt_hbsa                     0
# bt_hct                      0
# bt_mch                      0
# bt_mchc                     0
# bt_mvc                      0
# bt_plat                     0
# bt_rbc                      0
# bt_wbc                      0
# bt_rgpt                  1574
# bt_sgot                  1487
# bt_sgpt                     0
# bt_trig                   897
# new_judge_score             0
# new_bp_judge                0
# new_pulse_count_judge       0
# new_bt_chol_judge           0
# new_bt_crea_judge        1054
# new_bt_gluc_judge           0
# new_bt_hb_judge             0
# new_bt_hbsa_judge           0
# new_bt_hct_judge            0
# new_bt_mch_judge            0
# new_bt_mchc_judge           0
# new_bt_mvc_judge            0
# new_bt_plat_judge           0
# new_bt_rbc_judge            0
# new_bt_wbc_judge            0
# new_bt_rgpt_judge        1574
# new_bt_sgot_judge        1487
# new_bt_sgpt_judge           0
# new_bt_trig_judge         897
# risk                        0
# dtype: int64

# %%
new = df1.drop(['bt_crea','bt_rgpt','bt_sgot','bt_trig','new_bt_crea_judge','new_bt_rgpt_judge',
                'new_bt_sgot_judge','new_bt_trig_judge'], axis=1)

# %%
# null 값 없는 2470개의 데이터
new
# Out:
#      customer_id   profit review_cat judge  gender  age  insu_req_amount  \
# 8        C112856  2560180       혈액검사    재검       1   62           234820
# 10       C112878  3273889       혈액검사    승인       1   62           192320
# 12       C112899  1820000       혈액검사    승인       1   61                0
# 34       C113014  -531386       혈액검사    재검       1   61          2028243
# 51       C113102  -665483       혈액검사    재검       1   61             3100
# ...          ...      ...        ...   ...     ...  ...              ...
# 4483     C134165   282380       혈액검사    재검       2   48             5600
# 4485     C134172  2437230       혈액검사    재검       2   37            20900
# 4486     C134184  7137990       혈액검사    승인       2   53            73660
# 4490     C134221 -6351053       혈액검사    재검       2   51           623700
# 4491     C134227   837972       혈액검사    재검       2   45            42600
#
#       insu_pay_amount  insu_duration  insu_cum_amount  ...  new_bt_hbsa_judge  \
# 8              314820             23          2875000  ...                0.0
# 10             222320             24          3120000  ...                0.0
# 12            5000000             31          6820000  ...                0.0
# 34            2108243              3           375000  ...                0.0
# 51              29200              4           160000  ...                0.0
# ...               ...            ...              ...  ...                ...
# 4483             5600              8           320000  ...                1.0
# 4485           229900              4           400000  ...                1.0
# 4486            73660              2           440000  ...                0.0
# 4490          1103700              1           100000  ...                0.0
# 4491            42600              5           500000  ...                0.0
#
#       new_bt_hct_judge  new_bt_mch_judge  new_bt_mchc_judge  new_bt_mvc_judge  \
# 8                  0.0               0.0                0.0               0.0
# 10                 0.0               0.0                0.0               1.0
# 12                 0.0               0.0                0.0               0.0
# 34                 0.0               0.0                0.0               0.0
# 51                 0.0               0.0                0.0               0.0
# ...                ...               ...                ...               ...
# 4483               1.0               1.0                1.0               1.0
# 4485               0.0               0.0                0.0               1.0
# 4486               0.0               0.0                0.0               0.0
# 4490               0.0               0.0                0.0               0.0
# 4491               0.0               0.0                0.0               0.0
#
#       new_bt_plat_judge  new_bt_rbc_judge  new_bt_wbc_judge  \
# 8                   0.0               1.0               0.0
# 10                  0.0               0.0               0.0
# 12                  0.0               0.0               1.0
# 34                  0.0               0.0               0.0
# 51                  0.0               1.0               0.0
# ...                 ...               ...               ...
# 4483                0.0               0.0               0.0
# 4485                0.0               0.0               0.0
# 4486                0.0               0.0               0.0
# 4490                0.0               0.0               0.0
# 4491                0.0               0.0               0.0
#
#       new_bt_sgpt_judge  risk
# 8                   0.0     0
# 10                  0.0     0
# 12                  0.0     0
# 34                  0.0     1
# 51                  0.0     1
# ...                 ...   ...
# 4483                0.0     0
# 4485                0.0     0
# 4486                0.0     0
# 4490                0.0     1
# 4491                0.0     0
#
# [2456 rows x 47 columns]

# %%
# 데이터 구성
import pandas as pd

# 데이터 시각화
import matplotlib.pyplot as plt
import matplotlib

# 특성이 유사한 모델 선택, scaling 필요한 모델 제외
# DT, RF, GB, ANN
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier

# 모델 성능 평가 : F1 score, ROC curce, AUC
from sklearn.metrics import f1_score, roc_curve, auc, precision_score, recall_score
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler

import numpy as np

# 패키지 불러오기 
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale, minmax_scale, robust_scale
# %matplotlib inline

# 데이터 시각화(추세 등) 패키지
import seaborn as sns

# 추정검정 및 통계 분석 패키지
from scipy import stats
import scipy.stats
import statsmodels.api as sm
from statsmodels.stats.proportion import proportions_ztest

# 가설검정 및 통계 분석 패키지
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

from statsmodels.api import Logit
from sklearn.metrics import accuracy_score

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 8 to 4491
# Data columns (total 47 columns):
# customer_id              2456 non-null object
# profit                   2456 non-null int64
# review_cat               2456 non-null object
# judge                    2456 non-null object
# gender                   2456 non-null int64
# age                      2456 non-null int64
# insu_req_amount          2456 non-null int64
# insu_pay_amount          2456 non-null int64
# insu_duration            2456 non-null int64
# insu_cum_amount          2456 non-null int64
# height                   2456 non-null int64
# weight                   2456 non-null int64
# bust                     2456 non-null int64
# waist                    2456 non-null int64
# bmi                      2456 non-null float64
# whtr                     2456 non-null float64
# bp_min                   2456 non-null int64
# bp_max                   2456 non-null int64
# pulse_count              2456 non-null int64
# bt_chol                  2456 non-null float64
# bt_gluc                  2456 non-null float64
# bt_hb                    2456 non-null float64
# bt_hbsa                  2456 non-null object
# bt_hct                   2456 non-null float64
# bt_mch                   2456 non-null float64
# bt_mchc                  2456 non-null float64
# bt_mvc                   2456 non-null float64
# bt_plat                  2456 non-null float64
# bt_rbc                   2456 non-null float64
# bt_wbc                   2456 non-null float64
# bt_sgpt                  2456 non-null float64
# new_judge_score          2456 non-null int64
# new_bp_judge             2456 non-null int64
# new_pulse_count_judge    2456 non-null int64
# new_bt_chol_judge        2456 non-null float64
# new_bt_gluc_judge        2456 non-null float64
# new_bt_hb_judge          2456 non-null float64
# new_bt_hbsa_judge        2456 non-null float64
# new_bt_hct_judge         2456 non-null float64
# new_bt_mch_judge         2456 non-null float64
# new_bt_mchc_judge        2456 non-null float64
# new_bt_mvc_judge         2456 non-null float64
# new_bt_plat_judge        2456 non-null float64
# new_bt_rbc_judge         2456 non-null float64
# new_bt_wbc_judge         2456 non-null float64
# new_bt_sgpt_judge        2456 non-null float64
# risk                     2456 non-null int64
# dtypes: float64(25), int64(18), object(4)
# memory usage: 921.0+ KB

# %% [markdown]
# - 로지스틱 회귀분석

# %%
# 데이터 분할
df_train, df_test = train_test_split(new, test_size=0.3, random_state=1234)
print("Train data size:{}".format(df_train.shape))
print("Test data size:{}".format(df_test.shape))
# Out:
# Train data size:(1719, 47)
# Test data size:(737, 47)

# %% [markdown]
# - 혈액 검사 수치로 했을 때

# %%
# 모델 및 회귀계수 검토
log_model=Logit.from_formula("""risk~C(review_cat)+C(judge)+C(gender)+age+insu_req_amount+insu_pay_amount+insu_duration+insu_cum_amount+height+weight+bust+waist+bmi+whtr+bp_min+bp_max+pulse_count+bt_chol+bt_gluc+bt_hb+bt_hbsa+bt_hct+bt_mch+bt_mchc+bt_mvc+bt_plat+bt_rbc+bt_wbc+bt_sgpt+new_judge_score""",df_train)
# 적합
log_result=log_model.fit()
# 결과 출력
print(log_result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.245142
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   risk   No. Observations:                 1719
# Model:                          Logit   Df Residuals:                     1689
# Method:                           MLE   Df Model:                           29
# Date:                Fri, 08 May 2020   Pseudo R-squ.:                  0.3573
# Time:                        16:52:09   Log-Likelihood:                -421.40
# converged:                       True   LL-Null:                       -655.65
# Covariance Type:            nonrobust   LLR p-value:                 8.303e-81
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              25.7701     27.488      0.938      0.348     -28.105      79.646
# C(judge)[T.재검]         -0.0565      0.190     -0.297      0.767      -0.429       0.316
# C(gender)[T.2]          0.6279      0.433      1.451      0.147      -0.220       1.476
# bt_hbsa[T.POSITIVE]     0.1998      0.336      0.595      0.552      -0.459       0.859
# age                     0.0378      0.013      2.982      0.003       0.013       0.063
# insu_req_amount     -5.597e-07   2.89e-07     -1.935      0.053   -1.13e-06    7.11e-09
# insu_pay_amount      2.078e-06   2.01e-07     10.347      0.000    1.68e-06    2.47e-06
# insu_duration           0.0119      0.012      0.954      0.340      -0.013       0.036
# insu_cum_amount     -1.539e-06    1.8e-07     -8.553      0.000   -1.89e-06   -1.19e-06
# height                 -0.0873      0.158     -0.552      0.581      -0.397       0.223
# weight                  0.1627      0.195      0.834      0.404      -0.220       0.545
# bust                   -0.0073      0.024     -0.303      0.762      -0.055       0.040
# waist                  -0.0675      0.425     -0.159      0.874      -0.901       0.766
# bmi                    -0.3829      0.507     -0.755      0.450      -1.377       0.611
# whtr                    9.1841     67.944      0.135      0.892    -123.984     142.352
# bp_min                 -0.0261      0.026     -0.997      0.319      -0.077       0.025
# bp_max                  0.0087      0.019      0.459      0.646      -0.029       0.046
# pulse_count            -0.0041      0.018     -0.232      0.817      -0.039       0.031
# bt_chol                 0.0007      0.003      0.258      0.796      -0.005       0.006
# bt_gluc                -0.0025      0.010     -0.266      0.790      -0.021       0.016
# bt_hb                   0.6365      0.602      1.057      0.290      -0.543       1.816
# bt_hct                  0.1297      0.141      0.923      0.356      -0.146       0.405
# bt_mch                 -0.1434      0.255     -0.563      0.573      -0.642       0.356
# bt_mchc                 0.0274      0.110      0.250      0.802      -0.187       0.242
# bt_mvc                 -0.1396      0.081     -1.718      0.086      -0.299       0.020
# bt_plat                 0.0007      0.002      0.402      0.688      -0.003       0.004
# bt_rbc                 -0.0251      0.020     -1.224      0.221      -0.065       0.015
# bt_wbc              -2.952e-05   6.97e-05     -0.424      0.672      -0.000       0.000
# bt_sgpt                 0.0043      0.010      0.442      0.658      -0.015       0.023
# new_judge_score        -0.0004      0.088     -0.005      0.996      -0.174       0.173
# =======================================================================================

# %% [markdown]
# - 혈액 검사 수치 말고 판정 여부로 했을 때

# %%
# 모델 및 회귀계수 검토
log_model=Logit.from_formula("""risk~C(review_cat)+C(judge)+C(gender)+age+insu_req_amount+insu_pay_amount+insu_duration+insu_cum_amount+height+weight+bust+waist+bmi+whtr+bp_min+bp_max+pulse_count+C(new_bt_chol_judge)+C(new_bt_gluc_judge)+C(new_bt_hb_judge)+C(new_bt_hbsa_judge)+C(new_bt_hct_judge)+C(new_bt_mch_judge)+C(new_bt_mchc_judge)+C(new_bt_mvc_judge)+C(new_bt_plat_judge)+C(new_bt_rbc_judge)+C(new_bt_wbc_judge)+C(new_bt_sgpt_judge)+new_judge_score""",df_train)
# 적합
log_result=log_model.fit()
# 결과 출력
print(log_result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.244120
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   risk   No. Observations:                 1719
# Model:                          Logit   Df Residuals:                     1689
# Method:                           MLE   Df Model:                           29
# Date:                Fri, 08 May 2020   Pseudo R-squ.:                  0.3600
# Time:                        16:52:10   Log-Likelihood:                -419.64
# converged:                       True   LL-Null:                       -655.65
# Covariance Type:            nonrobust   LLR p-value:                 1.584e-81
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      21.7229     26.218      0.829      0.407     -29.664      73.110
# C(judge)[T.재검]                 -0.0548      0.190     -0.289      0.773      -0.427       0.317
# C(gender)[T.2]                  0.3891      0.390      0.997      0.319      -0.376       1.154
# C(new_bt_chol_judge)[T.1.0]    -0.7251      0.361     -2.009      0.044      -1.432      -0.018
# C(new_bt_gluc_judge)[T.1.0]    -0.6571      0.404     -1.625      0.104      -1.450       0.135
# C(new_bt_hb_judge)[T.1.0]      -1.1769      0.659     -1.787      0.074      -2.468       0.114
# C(new_bt_hbsa_judge)[T.1.0]    -0.0912      0.359     -0.254      0.800      -0.796       0.613
# C(new_bt_hct_judge)[T.1.0]      0.8814      0.514      1.716      0.086      -0.125       1.888
# C(new_bt_mch_judge)[T.1.0]     -0.1858      0.758     -0.245      0.806      -1.671       1.299
# C(new_bt_mchc_judge)[T.1.0]    -0.7018      0.392     -1.789      0.074      -1.471       0.067
# C(new_bt_mvc_judge)[T.1.0]     -0.9184      0.311     -2.950      0.003      -1.529      -0.308
# C(new_bt_plat_judge)[T.1.0]    -0.3664      0.485     -0.756      0.450      -1.317       0.584
# C(new_bt_rbc_judge)[T.1.0]     -0.3921      0.547     -0.717      0.473      -1.463       0.679
# C(new_bt_wbc_judge)[T.1.0]     -0.5730      0.945     -0.607      0.544      -2.425       1.279
# C(new_bt_sgpt_judge)[T.1.0]    -0.4674      0.581     -0.804      0.421      -1.607       0.672
# age                             0.0368      0.012      3.059      0.002       0.013       0.060
# insu_req_amount             -5.756e-07   2.88e-07     -1.997      0.046   -1.14e-06   -1.07e-08
# insu_pay_amount              2.066e-06   1.98e-07     10.432      0.000    1.68e-06    2.45e-06
# insu_duration                   0.0115      0.013      0.922      0.356      -0.013       0.036
# insu_cum_amount             -1.555e-06   1.81e-07     -8.578      0.000   -1.91e-06    -1.2e-06
# height                         -0.1471      0.164     -0.896      0.370      -0.469       0.175
# weight                          0.1465      0.197      0.742      0.458      -0.240       0.533
# bust                           -0.0073      0.024     -0.303      0.762      -0.055       0.040
# waist                           0.0785      0.437      0.180      0.857      -0.777       0.934
# bmi                            -0.3408      0.512     -0.666      0.505      -1.344       0.662
# whtr                          -13.3159     69.624     -0.191      0.848    -149.776     123.144
# bp_min                         -0.0347      0.026     -1.318      0.188      -0.086       0.017
# bp_max                          0.0139      0.019      0.724      0.469      -0.024       0.052
# pulse_count                    -0.0026      0.018     -0.144      0.885      -0.037       0.032
# new_judge_score                 0.3577      0.200      1.787      0.074      -0.035       0.750
# ===============================================================================================

# %%
y_pred=log_result.predict(df_test)
y_pred_class=(y_pred>0.5).astype(int)
y_pred_class.head()
# 실제 test 데이터의 목표변수의 test 데이터의 예측값 비교
print("Accuracy:{0:.3f}\n".format(accuracy_score(df_test["risk"], y_pred_class)))
print("Confusion Matrix:\n{}".format(confusion_matrix(df_test["risk"], y_pred_class)))
# Out:
# Accuracy:0.898
#
# Confusion Matrix:
# [[632   5]
#  [ 70  30]]

# %%
# 설명변수 중요도
df_logistic_coef=pd.DataFrame({"Coef":log_result.params.values[1:]}, index=log_model.exog_names[1:])
df_logistic_coef.plot.barh(y="Coef")
# Out:
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 8 to 4491
# Data columns (total 47 columns):
# customer_id              2456 non-null object
# profit                   2456 non-null int64
# review_cat               2456 non-null object
# judge                    2456 non-null object
# gender                   2456 non-null int64
# age                      2456 non-null int64
# insu_req_amount          2456 non-null int64
# insu_pay_amount          2456 non-null int64
# insu_duration            2456 non-null int64
# insu_cum_amount          2456 non-null int64
# height                   2456 non-null int64
# weight                   2456 non-null int64
# bust                     2456 non-null int64
# waist                    2456 non-null int64
# bmi                      2456 non-null float64
# whtr                     2456 non-null float64
# bp_min                   2456 non-null int64
# bp_max                   2456 non-null int64
# pulse_count              2456 non-null int64
# bt_chol                  2456 non-null float64
# bt_gluc                  2456 non-null float64
# bt_hb                    2456 non-null float64
# bt_hbsa                  2456 non-null object
# bt_hct                   2456 non-null float64
# bt_mch                   2456 non-null float64
# bt_mchc                  2456 non-null float64
# bt_mvc                   2456 non-null float64
# bt_plat                  2456 non-null float64
# bt_rbc                   2456 non-null float64
# bt_wbc                   2456 non-null float64
# bt_sgpt                  2456 non-null float64
# new_judge_score          2456 non-null int64
# new_bp_judge             2456 non-null int64
# new_pulse_count_judge    2456 non-null int64
# new_bt_chol_judge        2456 non-null float64
# new_bt_gluc_judge        2456 non-null float64
# new_bt_hb_judge          2456 non-null float64
# new_bt_hbsa_judge        2456 non-null float64
# new_bt_hct_judge         2456 non-null float64
# new_bt_mch_judge         2456 non-null float64
# new_bt_mchc_judge        2456 non-null float64
# new_bt_mvc_judge         2456 non-null float64
# new_bt_plat_judge        2456 non-null float64
# new_bt_rbc_judge         2456 non-null float64
# new_bt_wbc_judge         2456 non-null float64
# new_bt_sgpt_judge        2456 non-null float64
# risk                     2456 non-null int64
# dtypes: float64(25), int64(18), object(4)
# memory usage: 921.0+ KB

# %%
new['gender'] = new['gender'].astype('object')
new['new_bp_judge'] = new['new_bp_judge'].astype('object')
new['new_pulse_count_judge'] = new['new_pulse_count_judge'].astype('object')
new['new_bt_chol_judge'] = new['new_bt_chol_judge'].astype('object')
new['new_bt_gluc_judge'] = new['new_bt_gluc_judge'].astype('object')
new['new_bt_hb_judge'] = new['new_bt_hb_judge'].astype('object')
new['new_bt_hbsa_judge'] = new['new_bt_hbsa_judge'].astype('object')
new['new_bt_hct_judge'] = new['new_bt_hct_judge'].astype('object')
new['new_bt_mch_judge'] = new['new_bt_mch_judge'].astype('object')
new['new_bt_mchc_judge'] = new['new_bt_mchc_judge'].astype('object')
new['new_bt_mvc_judge'] = new['new_bt_mvc_judge'].astype('object')
new['new_bt_plat_judge'] = new['new_bt_plat_judge'].astype('object')
new['new_bt_rbc_judge'] = new['new_bt_rbc_judge'].astype('object')
new['new_bt_wbc_judge'] = new['new_bt_wbc_judge'].astype('object')
new['new_bt_sgpt_judge'] = new['new_bt_sgpt_judge'].astype('object')
# new['risk'] = new['risk'].astype('object')

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 8 to 4491
# Data columns (total 47 columns):
# customer_id              2456 non-null object
# profit                   2456 non-null int64
# review_cat               2456 non-null object
# judge                    2456 non-null object
# gender                   2456 non-null object
# age                      2456 non-null int64
# insu_req_amount          2456 non-null int64
# insu_pay_amount          2456 non-null int64
# insu_duration            2456 non-null int64
# insu_cum_amount          2456 non-null int64
# height                   2456 non-null int64
# weight                   2456 non-null int64
# bust                     2456 non-null int64
# waist                    2456 non-null int64
# bmi                      2456 non-null float64
# whtr                     2456 non-null float64
# bp_min                   2456 non-null int64
# bp_max                   2456 non-null int64
# pulse_count              2456 non-null int64
# bt_chol                  2456 non-null float64
# bt_gluc                  2456 non-null float64
# bt_hb                    2456 non-null float64
# bt_hbsa                  2456 non-null object
# bt_hct                   2456 non-null float64
# bt_mch                   2456 non-null float64
# bt_mchc                  2456 non-null float64
# bt_mvc                   2456 non-null float64
# bt_plat                  2456 non-null float64
# bt_rbc                   2456 non-null float64
# bt_wbc                   2456 non-null float64
# bt_sgpt                  2456 non-null float64
# new_judge_score          2456 non-null int64
# new_bp_judge             2456 non-null object
# new_pulse_count_judge    2456 non-null object
# new_bt_chol_judge        2456 non-null object
# new_bt_gluc_judge        2456 non-null object
# new_bt_hb_judge          2456 non-null object
# new_bt_hbsa_judge        2456 non-null object
# new_bt_hct_judge         2456 non-null object
# new_bt_mch_judge         2456 non-null object
# new_bt_mchc_judge        2456 non-null object
# new_bt_mvc_judge         2456 non-null object
# new_bt_plat_judge        2456 non-null object
# new_bt_rbc_judge         2456 non-null object
# new_bt_wbc_judge         2456 non-null object
# new_bt_sgpt_judge        2456 non-null object
# risk                     2456 non-null int64
# dtypes: float64(13), int64(15), object(19)
# memory usage: 921.0+ KB

# %% [markdown]
# - insu_duration / insu_cum_amount / insu_req_amount / insu_pay_amount : 돈 관련 제외하고 만들었을 때

# %%
# 모델 및 회귀계수 검토
log_model=Logit.from_formula("""risk~C(review_cat)+C(judge)+C(gender)+age+height+weight+bust+waist+bmi+whtr+bp_min+bp_max+pulse_count+C(new_bt_chol_judge)+C(new_bt_gluc_judge)+C(new_bt_hb_judge)+C(new_bt_hbsa_judge)+C(new_bt_hct_judge)+C(new_bt_mch_judge)+C(new_bt_mchc_judge)+C(new_bt_mvc_judge)+C(new_bt_plat_judge)+C(new_bt_rbc_judge)+C(new_bt_wbc_judge)+C(new_bt_sgpt_judge)+new_judge_score""",df_train)
# 적합
log_result=log_model.fit()
# 결과 출력
print(log_result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.369050
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   risk   No. Observations:                 1719
# Model:                          Logit   Df Residuals:                     1693
# Method:                           MLE   Df Model:                           25
# Date:                Fri, 08 May 2020   Pseudo R-squ.:                 0.03242
# Time:                        16:52:11   Log-Likelihood:                -634.40
# converged:                       True   LL-Null:                       -655.65
# Covariance Type:            nonrobust   LLR p-value:                   0.01585
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      16.8284     20.785      0.810      0.418     -23.910      57.567
# C(judge)[T.재검]                 -0.1529      0.154     -0.993      0.321      -0.454       0.149
# C(gender)[T.2]                  0.2660      0.303      0.878      0.380      -0.328       0.860
# C(new_bt_chol_judge)[T.1.0]    -0.3777      0.285     -1.326      0.185      -0.936       0.181
# C(new_bt_gluc_judge)[T.1.0]    -0.5763      0.327     -1.764      0.078      -1.217       0.064
# C(new_bt_hb_judge)[T.1.0]      -1.1918      0.587     -2.032      0.042      -2.342      -0.042
# C(new_bt_hbsa_judge)[T.1.0]     0.1640      0.297      0.553      0.580      -0.417       0.745
# C(new_bt_hct_judge)[T.1.0]      0.8830      0.432      2.042      0.041       0.036       1.730
# C(new_bt_mch_judge)[T.1.0]      0.2421      0.675      0.359      0.720      -1.081       1.565
# C(new_bt_mchc_judge)[T.1.0]    -0.4728      0.313     -1.508      0.131      -1.087       0.142
# C(new_bt_mvc_judge)[T.1.0]     -0.4495      0.241     -1.862      0.063      -0.922       0.024
# C(new_bt_plat_judge)[T.1.0]    -0.0935      0.410     -0.228      0.819      -0.896       0.709
# C(new_bt_rbc_judge)[T.1.0]     -0.2647      0.502     -0.527      0.598      -1.249       0.720
# C(new_bt_wbc_judge)[T.1.0]     -0.8782      0.762     -1.153      0.249      -2.371       0.614
# C(new_bt_sgpt_judge)[T.1.0]     0.0349      0.462      0.076      0.940      -0.870       0.940
# age                             0.0402      0.010      3.911      0.000       0.020       0.060
# height                         -0.1248      0.130     -0.962      0.336      -0.379       0.130
# weight                          0.0887      0.165      0.537      0.592      -0.235       0.413
# bust                           -0.0144      0.020     -0.725      0.469      -0.054       0.025
# waist                           0.1063      0.357      0.298      0.766      -0.593       0.805
# bmi                            -0.1848      0.428     -0.432      0.666      -1.024       0.654
# whtr                          -17.5423     56.863     -0.308      0.758    -128.992      93.908
# bp_min                         -0.0236      0.022     -1.094      0.274      -0.066       0.019
# bp_max                          0.0043      0.016      0.278      0.781      -0.026       0.035
# pulse_count                     0.0151      0.015      1.031      0.303      -0.014       0.044
# new_judge_score                 0.1543      0.156      0.987      0.324      -0.152       0.461
# ===============================================================================================

# %%
# 모델 및 회귀계수 검토
log_model=Logit.from_formula("""risk~C(review_cat)+C(judge)+C(gender)+age+height+weight+bust+waist+bmi+whtr+bp_min+bp_max+pulse_count+bt_chol+bt_gluc+bt_hb+bt_hbsa+bt_hct+bt_mch+bt_mchc+bt_mvc+bt_plat+bt_rbc+bt_wbc+bt_sgpt+new_judge_score""",df_train)
# 적합
log_result=log_model.fit()
# 결과 출력
print(log_result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.371505
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   risk   No. Observations:                 1719
# Model:                          Logit   Df Residuals:                     1693
# Method:                           MLE   Df Model:                           25
# Date:                Fri, 08 May 2020   Pseudo R-squ.:                 0.02598
# Time:                        16:52:12   Log-Likelihood:                -638.62
# converged:                       True   LL-Null:                       -655.65
# Covariance Type:            nonrobust   LLR p-value:                    0.1066
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              23.7137     22.126      1.072      0.284     -19.653      67.080
# C(judge)[T.재검]         -0.1457      0.154     -0.946      0.344      -0.448       0.156
# C(gender)[T.2]          0.3783      0.347      1.089      0.276      -0.302       1.059
# bt_hbsa[T.POSITIVE]     0.3357      0.274      1.225      0.220      -0.201       0.873
# age                     0.0417      0.011      3.911      0.000       0.021       0.063
# height                 -0.0991      0.129     -0.769      0.442      -0.352       0.153
# weight                  0.0992      0.165      0.600      0.548      -0.225       0.423
# bust                   -0.0136      0.020     -0.683      0.495      -0.053       0.025
# waist                   0.0417      0.351      0.119      0.905      -0.646       0.729
# bmi                    -0.2111      0.427     -0.494      0.621      -1.049       0.627
# whtr                   -7.0823     55.974     -0.127      0.899    -116.789     102.625
# bp_min                 -0.0225      0.021     -1.049      0.294      -0.065       0.020
# bp_max                  0.0024      0.015      0.155      0.877      -0.028       0.032
# pulse_count             0.0145      0.015      0.998      0.318      -0.014       0.043
# bt_chol                -0.0003      0.002     -0.148      0.882      -0.005       0.004
# bt_gluc                -0.0041      0.007     -0.591      0.555      -0.018       0.010
# bt_hb                   0.6272      0.469      1.338      0.181      -0.291       1.546
# bt_hct                  0.1048      0.112      0.936      0.349      -0.115       0.324
# bt_mch                 -0.2557      0.201     -1.273      0.203      -0.649       0.138
# bt_mchc                 0.0604      0.089      0.680      0.496      -0.114       0.235
# bt_mvc                 -0.0715      0.064     -1.120      0.263      -0.197       0.054
# bt_plat                 0.0010      0.001      0.706      0.480      -0.002       0.004
# bt_rbc                 -0.0254      0.016     -1.625      0.104      -0.056       0.005
# bt_wbc              -3.199e-05   5.69e-05     -0.562      0.574      -0.000    7.96e-05
# bt_sgpt                 0.0011      0.006      0.183      0.855      -0.011       0.013
# new_judge_score        -0.0287      0.070     -0.411      0.681      -0.166       0.108
# =======================================================================================

# %% [markdown]
# ### 의사결정나무

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.api import Logit
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz
from sklearn.model_selection import GridSearchCV
from sklearn.tree import export_graphviz
import graphviz

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 8 to 4491
# Data columns (total 47 columns):
# customer_id              2456 non-null object
# profit                   2456 non-null int64
# review_cat               2456 non-null object
# judge                    2456 non-null object
# gender                   2456 non-null object
# age                      2456 non-null int64
# insu_req_amount          2456 non-null int64
# insu_pay_amount          2456 non-null int64
# insu_duration            2456 non-null int64
# insu_cum_amount          2456 non-null int64
# height                   2456 non-null int64
# weight                   2456 non-null int64
# bust                     2456 non-null int64
# waist                    2456 non-null int64
# bmi                      2456 non-null float64
# whtr                     2456 non-null float64
# bp_min                   2456 non-null int64
# bp_max                   2456 non-null int64
# pulse_count              2456 non-null int64
# bt_chol                  2456 non-null float64
# bt_gluc                  2456 non-null float64
# bt_hb                    2456 non-null float64
# bt_hbsa                  2456 non-null object
# bt_hct                   2456 non-null float64
# bt_mch                   2456 non-null float64
# bt_mchc                  2456 non-null float64
# bt_mvc                   2456 non-null float64
# bt_plat                  2456 non-null float64
# bt_rbc                   2456 non-null float64
# bt_wbc                   2456 non-null float64
# bt_sgpt                  2456 non-null float64
# new_judge_score          2456 non-null int64
# new_bp_judge             2456 non-null object
# new_pulse_count_judge    2456 non-null object
# new_bt_chol_judge        2456 non-null object
# new_bt_gluc_judge        2456 non-null object
# new_bt_hb_judge          2456 non-null object
# new_bt_hbsa_judge        2456 non-null object
# new_bt_hct_judge         2456 non-null object
# new_bt_mch_judge         2456 non-null object
# new_bt_mchc_judge        2456 non-null object
# new_bt_mvc_judge         2456 non-null object
# new_bt_plat_judge        2456 non-null object
# new_bt_rbc_judge         2456 non-null object
# new_bt_wbc_judge         2456 non-null object
# new_bt_sgpt_judge        2456 non-null object
# risk                     2456 non-null int64
# dtypes: float64(13), int64(15), object(19)
# memory usage: 921.0+ KB

# %%
df_end = new.drop(['customer_id','insu_req_amount',
                   'insu_pay_amount','insu_cum_amount','profit','insu_duration','judge']
                   ,axis=1,inplace=False)
df_end.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 8 to 4491
# Data columns (total 40 columns):
# review_cat               2456 non-null object
# gender                   2456 non-null object
# age                      2456 non-null int64
# height                   2456 non-null int64
# weight                   2456 non-null int64
# bust                     2456 non-null int64
# waist                    2456 non-null int64
# bmi                      2456 non-null float64
# whtr                     2456 non-null float64
# bp_min                   2456 non-null int64
# bp_max                   2456 non-null int64
# pulse_count              2456 non-null int64
# bt_chol                  2456 non-null float64
# bt_gluc                  2456 non-null float64
# bt_hb                    2456 non-null float64
# bt_hbsa                  2456 non-null object
# bt_hct                   2456 non-null float64
# bt_mch                   2456 non-null float64
# bt_mchc                  2456 non-null float64
# bt_mvc                   2456 non-null float64
# bt_plat                  2456 non-null float64
# bt_rbc                   2456 non-null float64
# bt_wbc                   2456 non-null float64
# bt_sgpt                  2456 non-null float64
# new_judge_score          2456 non-null int64
# new_bp_judge             2456 non-null object
# new_pulse_count_judge    2456 non-null object
# new_bt_chol_judge        2456 non-null object
# new_bt_gluc_judge        2456 non-null object
# new_bt_hb_judge          2456 non-null object
# new_bt_hbsa_judge        2456 non-null object
# new_bt_hct_judge         2456 non-null object
# new_bt_mch_judge         2456 non-null object
# new_bt_mchc_judge        2456 non-null object
# new_bt_mvc_judge         2456 non-null object
# new_bt_plat_judge        2456 non-null object
# new_bt_rbc_judge         2456 non-null object
# new_bt_wbc_judge         2456 non-null object
# new_bt_sgpt_judge        2456 non-null object
# risk                     2456 non-null int64
# dtypes: float64(13), int64(10), object(17)
# memory usage: 786.7+ KB

# %%
pf_end = pd.get_dummies(df_end)
pf_end.head()
df_end = pf_end
df_end
# Out:
#       age  height  weight  bust  waist        bmi      whtr  bp_min  bp_max  \
# 8      62     165      70    96     82  25.711662  0.496970      80     130
# 10     62     172      61    90     73  20.619254  0.424419      80     120
# 12     61     162      68    96     85  25.910684  0.524691      80     120
# 34     61     170      71   100     84  24.567474  0.494118      85     125
# 51     61     165      63    96     83  23.140496  0.503030      80     125
# ...   ...     ...     ...   ...    ...        ...       ...     ...     ...
# 4483   48     162      67   101     82  25.529645  0.506173      80     120
# 4485   37     160      70    99     91  27.343750  0.568750      80     120
# 4486   53     155      62    94     82  25.806452  0.529032      85     120
# 4490   51     159      52    85     72  20.568807  0.452830      70     110
# 4491   45     153      45    88     74  19.223376  0.483660      80     120
#
#       pulse_count  ...  new_bt_mvc_judge_0.0  new_bt_mvc_judge_1.0  \
# 8              64  ...                     1                     0
# 10             60  ...                     0                     1
# 12             72  ...                     1                     0
# 34             76  ...                     1                     0
# 51             70  ...                     1                     0
# ...           ...  ...                   ...                   ...
# 4483           68  ...                     0                     1
# 4485           68  ...                     0                     1
# 4486           64  ...                     1                     0
# 4490           72  ...                     1                     0
# 4491           76  ...                     1                     0
#
#       new_bt_plat_judge_0.0  new_bt_plat_judge_1.0  new_bt_rbc_judge_0.0  \
# 8                         1                      0                     0
# 10                        1                      0                     1
# 12                        1                      0                     1
# 34                        1                      0                     1
# 51                        1                      0                     0
# ...                     ...                    ...                   ...
# 4483                      1                      0                     1
# 4485                      1                      0                     1
# 4486                      1                      0                     1
# 4490                      1                      0                     1
# 4491                      1                      0                     1
#
#       new_bt_rbc_judge_1.0  new_bt_wbc_judge_0.0  new_bt_wbc_judge_1.0  \
# 8                        1                     1                     0
# 10                       0                     1                     0
# 12                       0                     0                     1
# 34                       0                     1                     0
# 51                       1                     1                     0
# ...                    ...                   ...                   ...
# 4483                     0                     1                     0
# 4485                     0                     1                     0
# 4486                     0                     1                     0
# 4490                     0                     1                     0
# 4491                     0                     1                     0
#
#       new_bt_sgpt_judge_0.0  new_bt_sgpt_judge_1.0
# 8                         1                      0
# 10                        1                      0
# 12                        1                      0
# 34                        1                      0
# 51                        1                      0
# ...                     ...                    ...
# 4483                      1                      0
# 4485                      1                      0
# 4486                      1                      0
# 4490                      1                      0
# 4491                      1                      0
#
# [2456 rows x 56 columns]

# %%
df_raw_y=df_end["risk"]
df_raw_x=df_end.drop("risk", axis=1, inplace=False)

# %%
# 데이터 분할
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_raw_x,df_raw_y,test_size = 0.3, random_state = 1234)
df_train_x, df_val_x, df_train_y, df_val_y = train_test_split(df_train_x,df_train_y,test_size = 3/7, random_state=1234)
print("train data X size : {}".format(df_train_x.shape))
print("train data Y size : {}".format(df_train_y.shape))
print("validation data X size : {}".format(df_val_x.shape))
print("validation data Y size : {}".format(df_val_y.shape))
print("test data X size : {}".format(df_test_x.shape))
print("test data Y size : {}".format(df_test_y.shape))
# Out:
# train data X size : (982, 55)
# train data Y size : (982,)
# validation data X size : (737, 55)
# validation data Y size : (737,)
# test data X size : (737, 55)
# test data Y size : (737,)

# %%
# 모델 생성
tree_uncustomized = DecisionTreeClassifier(random_state=1234)
tree_uncustomized.fit(df_train_x, df_train_y)
# Train 데이터 설명력
print("Accuracy on training set:{:.3f}".format(tree_uncustomized.score(df_train_x, df_train_y)))
# Validation 데이터 설명력
print("Accuracy on validation set:{:.3f}".format(tree_uncustomized.score(df_val_x, df_val_y)))
# Out:
# Accuracy on training set:1.000
# Accuracy on validation set:0.730

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
valid_accuracy= []

# max_depth : 최대 깊이 변경
para_depth=[depth for depth in range(1,11)]

for v_max_depth in para_depth:
    tree=DecisionTreeClassifier(max_depth=v_max_depth, random_state=1234)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    valid_accuracy.append(tree.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_depth = pd.DataFrame()
df_accuracy_depth["Depth"]=para_depth
df_accuracy_depth["TrainAccuracy"]=train_accuracy
df_accuracy_depth["ValidAccuracy"]=valid_accuracy

# %%
# 모델 정확도 확인
df_accuracy_depth.round(3)
# Out:
#    Depth  TrainAccuracy  ValidAccuracy
# 0      1          0.864          0.885
# 1      2          0.864          0.885
# 2      3          0.871          0.872
# 3      4          0.875          0.874
# 4      5          0.885          0.868
# 5      6          0.888          0.864
# 6      7          0.894          0.841
# 7      8          0.902          0.836
# 8      9          0.916          0.824
# 9     10          0.930          0.801

# %%
# 모델 정확도 그래프 확인
plt.plot(para_depth, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_depth, valid_accuracy, linestyle="--", label="Validation Accuracy")
plt.legend()

# %%
# 변수명 저장
v_feature_name = df_train_x.columns
tree_low = DecisionTreeClassifier(max_depth=1,random_state=1234)
tree_low.fit(df_train_x, df_train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=1234, splitter='best')

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
valid_accuracy= []

# min_samples_split : 분할하기 위한 노드의 최소 샘플 수
para_split=[n_split*2 for n_split in range(1,11)]

for v_min_samples_split in para_split:
    tree=DecisionTreeClassifier(min_samples_split=v_min_samples_split, max_depth=1, random_state=1234)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    valid_accuracy.append(tree.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_split = pd.DataFrame()
df_accuracy_split["MinSamplesSplit"]=para_split
df_accuracy_split["TrainAccuracy"]=train_accuracy
df_accuracy_split["ValidationAccuracy"]=valid_accuracy

# %%
df_accuracy_split.round(3)
# Out:
#    MinSamplesSplit  TrainAccuracy  ValidationAccuracy
# 0                2          0.864               0.885
# 1                4          0.864               0.885
# 2                6          0.864               0.885
# 3                8          0.864               0.885
# 4               10          0.864               0.885
# 5               12          0.864               0.885
# 6               14          0.864               0.885
# 7               16          0.864               0.885
# 8               18          0.864               0.885
# 9               20          0.864               0.885

# %%
# 모델 정확도 그래프 확인
plt.plot(para_split, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_split, valid_accuracy, linestyle="--", label="Validation Accuracy")
plt.legend()

# %%
# 깊이가 3 모델
tree_low=DecisionTreeClassifier(max_depth=1, min_samples_split = 2, random_state=1234)
tree_low.fit(df_train_x, df_train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=1234, splitter='best')

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
valid_accuracy= []

# min_samples_leaf : 잎사귀 노드 최소 자료 수 제한
para_leaf=[n_leaf*2 for n_leaf in range(1,11)]

for v_min_samples_leaf in para_leaf:
    tree=DecisionTreeClassifier(min_samples_leaf=v_min_samples_leaf,min_samples_split=2,
                                max_depth=1, random_state=1234)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    valid_accuracy.append(tree.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_leaf = pd.DataFrame()
df_accuracy_leaf["MinSamplesLeaf"]=para_depth
df_accuracy_leaf["TrainAccuracy"]=train_accuracy
df_accuracy_leaf["ValidAccuracy"]=valid_accuracy

# %%
# 모델 정확도 확인
df_accuracy_leaf.round(3)
# Out:
#    MinSamplesLeaf  TrainAccuracy  ValidAccuracy
# 0               1          0.864          0.885
# 1               2          0.864          0.885
# 2               3          0.864          0.885
# 3               4          0.864          0.885
# 4               5          0.864          0.885
# 5               6          0.864          0.885
# 6               7          0.864          0.885
# 7               8          0.864          0.885
# 8               9          0.864          0.885
# 9              10          0.864          0.885

# %%
# 모델 정확도 그래프 확인
plt.plot(para_leaf, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_leaf, valid_accuracy, linestyle="--", label="Valid Accuracy")
plt.legend()

# %%
dt_tree_final=DecisionTreeClassifier(max_depth=1, min_samples_split=2, min_samples_leaf=2, random_state=1234)
dt_tree_final.fit(df_test_x, df_test_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=1234, splitter='best')

# %%
# 평가
y_pred=dt_tree_final.predict(df_test_x)
print("Accuracy:{0:.3f}\n".format(dt_tree_final.score(df_test_x, df_test_y)))
print("Confusion matrix:\n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy:0.864
#
# Confusion matrix:
# [[637   0]
#  [100   0]]

# %%
# 설명변수 중요도 확인 및 테이블 저장
df_importance=pd.DataFrame()
df_importance["Feature"]=v_feature_name
df_importance["Importance"]=dt_tree_final.feature_importances_
# 테이블을 중요도 순으로 정렬
df_importance.sort_values("Importance", ascending=False, inplace=True)
df_importance.round(3)
# Out:
#                     Feature  Importance
# 6                      whtr         1.0
# 0                       age         0.0
# 41     new_bt_mch_judge_0.0         0.0
# 30  new_pulse_count_judge_1         0.0
# 31    new_bt_chol_judge_0.0         0.0
# 32    new_bt_chol_judge_1.0         0.0
# 33    new_bt_gluc_judge_0.0         0.0
# 34    new_bt_gluc_judge_1.0         0.0
# 35      new_bt_hb_judge_0.0         0.0
# 36      new_bt_hb_judge_1.0         0.0
# 37    new_bt_hbsa_judge_0.0         0.0
# 38    new_bt_hbsa_judge_1.0         0.0
# 39     new_bt_hct_judge_0.0         0.0
# 40     new_bt_hct_judge_1.0         0.0
# 42     new_bt_mch_judge_1.0         0.0
# 28           new_bp_judge_1         0.0
# 43    new_bt_mchc_judge_0.0         0.0
# 44    new_bt_mchc_judge_1.0         0.0
# 45     new_bt_mvc_judge_0.0         0.0
# 46     new_bt_mvc_judge_1.0         0.0
# 47    new_bt_plat_judge_0.0         0.0
# 48    new_bt_plat_judge_1.0         0.0
# 49     new_bt_rbc_judge_0.0         0.0
# 50     new_bt_rbc_judge_1.0         0.0
# 51     new_bt_wbc_judge_0.0         0.0
# 52     new_bt_wbc_judge_1.0         0.0
# 53    new_bt_sgpt_judge_0.0         0.0
# 29  new_pulse_count_judge_0         0.0
# 27           new_bp_judge_0         0.0
# 1                    height         0.0
# 26         bt_hbsa_POSITIVE         0.0
# 2                    weight         0.0
# 3                      bust         0.0
# 4                     waist         0.0
# 5                       bmi         0.0
# 7                    bp_min         0.0
# 8                    bp_max         0.0
# 9               pulse_count         0.0
# 10                  bt_chol         0.0
# 11                  bt_gluc         0.0
# 12                    bt_hb         0.0
# 13                   bt_hct         0.0
# 14                   bt_mch         0.0
# 15                  bt_mchc         0.0
# 16                   bt_mvc         0.0
# 17                  bt_plat         0.0
# 18                   bt_rbc         0.0
# 19                   bt_wbc         0.0
# 20                  bt_sgpt         0.0
# 21          new_judge_score         0.0
# 22          review_cat_혈액검사         0.0
# 23                 gender_1         0.0
# 24                 gender_2         0.0
# 25         bt_hbsa_NEGATIVE         0.0
# 54    new_bt_sgpt_judge_1.0         0.0

# %%
# 설명변수 중요도 그래프
# 중요도가 높은 변수를 상위에 그림
df_importance.sort_values("Importance", ascending=True, inplace=True)
coordinates=range(len(df_importance))
plt.barh(y=coordinates, width=df_importance["Importance"])
plt.yticks(coordinates, df_importance["Feature"])
plt.xlabel("설명변수 중요도")
plt.ylabel("설명변수")
# Out:
# Text(0, 0.5, '설명변수')
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54792 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54792 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# GridSearchCV를 이용한 최적 parameter 찾기
estimator=DecisionTreeClassifier()
# 구하고자 하는 parameter와 범위
param_grid={"max_depth":para_depth, "min_samples_split":para_split,
           "min_samples_leaf":para_leaf}
# 정확도가 높은 최적 parameter 찾기
grid_dt=GridSearchCV(estimator, param_grid, scoring="accuracy", n_jobs=-1)
grid_dt.fit(df_train_x, df_train_y)

print("best estimator model:\n{}".format(grid_dt.best_estimator_))
print("\nbest parameter:\n{}".format(grid_dt.best_params_))
print("\nbest score:\n{}".format(grid_dt.best_score_.round(3)))
# Out:
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# best estimator model:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=6, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
#
# best parameter:
# {'max_depth': 1, 'min_samples_leaf': 6, 'min_samples_split': 2}
#
# best score:
# 0.864

# %% [markdown]
# ### 랜덤 포레스트

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
df_end = new.drop(['customer_id','insu_req_amount',
                   'insu_pay_amount','insu_cum_amount','profit','insu_duration']
                   ,axis=1,inplace=False)
df_end.info()
pf_end = pd.get_dummies(df_end)
pf_end.head()
df_end = pf_end
df_end
df_raw_y=df_end["risk"]
df_raw_x=df_end.drop("risk", axis=1, inplace=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 8 to 4491
# Data columns (total 41 columns):
# review_cat               2456 non-null object
# judge                    2456 non-null object
# gender                   2456 non-null object
# age                      2456 non-null int64
# height                   2456 non-null int64
# weight                   2456 non-null int64
# bust                     2456 non-null int64
# waist                    2456 non-null int64
# bmi                      2456 non-null float64
# whtr                     2456 non-null float64
# bp_min                   2456 non-null int64
# bp_max                   2456 non-null int64
# pulse_count              2456 non-null int64
# bt_chol                  2456 non-null float64
# bt_gluc                  2456 non-null float64
# bt_hb                    2456 non-null float64
# bt_hbsa                  2456 non-null object
# bt_hct                   2456 non-null float64
# bt_mch                   2456 non-null float64
# bt_mchc                  2456 non-null float64
# bt_mvc                   2456 non-null float64
# bt_plat                  2456 non-null float64
# bt_rbc                   2456 non-null float64
# bt_wbc                   2456 non-null float64
# bt_sgpt                  2456 non-null float64
# new_judge_score          2456 non-null int64
# new_bp_judge             2456 non-null object
# new_pulse_count_judge    2456 non-null object
# new_bt_chol_judge        2456 non-null object
# new_bt_gluc_judge        2456 non-null object
# new_bt_hb_judge          2456 non-null object
# new_bt_hbsa_judge        2456 non-null object
# new_bt_hct_judge         2456 non-null object
# new_bt_mch_judge         2456 non-null object
# new_bt_mchc_judge        2456 non-null object
# new_bt_mvc_judge         2456 non-null object
# new_bt_plat_judge        2456 non-null object
# new_bt_rbc_judge         2456 non-null object
# new_bt_wbc_judge         2456 non-null object
# new_bt_sgpt_judge        2456 non-null object
# risk                     2456 non-null int64
# dtypes: float64(13), int64(10), object(18)
# memory usage: 805.9+ KB

# %%
# 랜덤 포레스트 모델 생성
rf_uncustomized=RandomForestClassifier(random_state=1234)
rf_uncustomized.fit(df_train_x, df_train_y)
# train 데이터셋 정확도
print("Accuracy on training set:{:.3f}".format(rf_uncustomized.score(df_train_x, df_train_y)))
# Validation 데이터 설명력
print("Accuracy on validation set:{:.3f}".format(rf_uncustomized.score(df_val_x, df_val_y)))
# Out:
# Accuracy on training set:0.971
# Accuracy on validation set:0.878
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
valid_accuracy= []

# n_estimators : 트리수 변경 1~150
para_n_tree=[n_tree*10 for n_tree in range(1,16)]

for v_n_estimators in para_n_tree:
    tree=RandomForestClassifier(n_estimators=v_n_estimators, random_state=1234)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    valid_accuracy.append(tree.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_n = pd.DataFrame()
df_accuracy_n["n_estimators"]=para_n_tree
df_accuracy_n["TrainAccuracy"]=train_accuracy
df_accuracy_n["ValidAccuracy"]=valid_accuracy

# %%
# 모델 정확도 확인
df_accuracy_n.round(3)
# Out:
#     n_estimators  TrainAccuracy  ValidAccuracy
# 0             10          0.971          0.878
# 1             20          0.987          0.881
# 2             30          0.995          0.879
# 3             40          0.999          0.883
# 4             50          1.000          0.883
# 5             60          1.000          0.885
# 6             70          1.000          0.883
# 7             80          1.000          0.883
# 8             90          1.000          0.883
# 9            100          1.000          0.883
# 10           110          1.000          0.883
# 11           120          1.000          0.883
# 12           130          1.000          0.885
# 13           140          1.000          0.885
# 14           150          1.000          0.885

# %%
# 모델 정확도 그래프 확인
plt.plot(para_n_tree, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_n_tree, valid_accuracy, linestyle="--", label="Validation Accuracy")
plt.xlabel("n_estimators")
plt.ylabel("accuracy")
plt.legend()

# %%
# error 저장 리스트
oob_error=[]
for v_n_estimator in range(1,151):
    rf=RandomForestClassifier(n_estimators=v_n_estimator, oob_score=True,
                             random_state=1234)
    rf.fit(df_train_x, df_train_y)
    oob_error.append(1-rf.oob_score_)
# Out:
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\jykan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %%
# 그래프로 표현
plt.plot(range(1,151),oob_error)
plt.ylabel("oob error")
plt.xlabel("n_estimators")
# Out:
# Text(0.5, 0, 'n_estimators')

# %%
# 트리수 지정
n_estimators=100

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
valid_accuracy= []

# max_depth : 최대 깊이 변경
para_depth=[depth for depth in range(1,11)]

for v_max_depth in para_depth:
    tree=RandomForestClassifier(max_depth=v_max_depth,
                                n_estimators=100
                                ,random_state=1234)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    valid_accuracy.append(tree.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_depth = pd.DataFrame()
df_accuracy_depth["Depth"]=para_depth
df_accuracy_depth["TrainAccuracy"]=train_accuracy
df_accuracy_depth["ValidAccuracy"]=valid_accuracy

# %%
# 모델 정확도 확인
df_accuracy_depth.round(3)
# Out:
#    Depth  TrainAccuracy  ValidAccuracy
# 0      1          0.864          0.885
# 1      2          0.864          0.885
# 2      3          0.864          0.885
# 3      4          0.864          0.885
# 4      5          0.864          0.885
# 5      6          0.865          0.885
# 6      7          0.868          0.885
# 7      8          0.874          0.885
# 8      9          0.896          0.885
# 9     10          0.921          0.885

# %%
# 모델 정확도 그래프 확인
plt.plot(para_depth, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_depth, valid_accuracy, linestyle="--", label="Validation Accuracy")
plt.xlabel("max depth")
plt.ylabel("accuracy")
plt.legend()

# %%
# 최대 깊이 지정
max_depth=10

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
valid_accuracy= []

# min_samples_split : 분할하기 위한 노드의 최소 샘플 수
para_split=[n_split*10 for n_split in range(1,11)]

for v_min_samples_split in para_split:
    tree=RandomForestClassifier(n_estimators=100,
                                min_samples_split=v_min_samples_split, 
                                max_depth=10, random_state=1234)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    valid_accuracy.append(tree.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_split = pd.DataFrame()
df_accuracy_split["MinSamplesSplit"]=para_split
df_accuracy_split["TrainAccuracy"]=train_accuracy
df_accuracy_split["ValidationAccuracy"]=valid_accuracy

# %%
df_accuracy_split.round(3)
# Out:
#    MinSamplesSplit  TrainAccuracy  ValidationAccuracy
# 0               10          0.870               0.885
# 1               20          0.865               0.885
# 2               30          0.864               0.885
# 3               40          0.864               0.885
# 4               50          0.864               0.885
# 5               60          0.864               0.885
# 6               70          0.864               0.885
# 7               80          0.864               0.885
# 8               90          0.864               0.885
# 9              100          0.864               0.885

# %%
# 모델 정확도 그래프 확인
plt.plot(para_split, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_split, valid_accuracy, linestyle="--", label="Validation Accuracy")
plt.legend()

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
valid_accuracy= []

# min_samples_leaf : 잎사귀 노드 최소 자료 수 제한
para_leaf=[n_leaf*10 for n_leaf in range(1,11)]

for v_min_samples_leaf in para_leaf:
    rf=RandomForestClassifier(n_estimators=100,
                              min_samples_leaf=v_min_samples_leaf,
                              min_samples_split=10,
                                max_depth=10, random_state=1234)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    valid_accuracy.append(tree.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_leaf = pd.DataFrame()
df_accuracy_leaf["MinSamplesLeaf"]=para_depth
df_accuracy_leaf["TrainAccuracy"]=train_accuracy
df_accuracy_leaf["ValidAccuracy"]=valid_accuracy

# %%
# 모델 정확도 확인
df_accuracy_leaf.round(3)
# Out:
#    MinSamplesLeaf  TrainAccuracy  ValidAccuracy
# 0               1          0.864          0.885
# 1               2          0.864          0.885
# 2               3          0.864          0.885
# 3               4          0.864          0.885
# 4               5          0.864          0.885
# 5               6          0.864          0.885
# 6               7          0.864          0.885
# 7               8          0.864          0.885
# 8               9          0.864          0.885
# 9              10          0.864          0.885

# %%
# 모델 정확도 그래프 확인
plt.plot(para_leaf, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_leaf, valid_accuracy, linestyle="--", label="Valid Accuracy")
plt.legend()

# %%
rf_tree_final=RandomForestClassifier(n_estimators=100, max_depth=1, min_samples_split=2, min_samples_leaf=10, random_state=1234)
rf_tree_final.fit(df_test_x, df_test_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=1, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=10, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=1234,
#                        verbose=0, warm_start=False)

# %%
# 변수명
v_feature_name=df_train_x.columns
# 설명변수 중요도 확인 및 테이블 저장
df_importance=pd.DataFrame()
df_importance["Feature"]=v_feature_name
df_importance["Importance"]=rf_tree_final.feature_importances_
# 테이블을 중요도 순으로 정렬
df_importance.sort_values("Importance", ascending=False, inplace=True)
df_importance.round(3)
# Out:
#                     Feature  Importance
# 3                      bust        0.09
# 10                  bt_chol        0.07
# 18                   bt_rbc        0.07
# 2                    weight        0.06
# 5                       bmi        0.06
# 0                       age        0.05
# 1                    height        0.05
# 11                  bt_gluc        0.05
# 14                   bt_mch        0.05
# 17                  bt_plat        0.05
# 4                     waist        0.04
# 49     new_bt_rbc_judge_0.0        0.04
# 8                    bp_max        0.04
# 20                  bt_sgpt        0.04
# 50     new_bt_rbc_judge_1.0        0.03
# 16                   bt_mvc        0.02
# 19                   bt_wbc        0.02
# 15                  bt_mchc        0.02
# 9               pulse_count        0.02
# 7                    bp_min        0.02
# 6                      whtr        0.02
# 12                    bt_hb        0.02
# 21          new_judge_score        0.01
# 13                   bt_hct        0.01
# 43    new_bt_mchc_judge_0.0        0.01
# 33    new_bt_gluc_judge_0.0        0.01
# 32    new_bt_chol_judge_1.0        0.01
# 41     new_bt_mch_judge_0.0        0.01
# 26         bt_hbsa_POSITIVE        0.01
# 40     new_bt_hct_judge_1.0        0.00
# 48    new_bt_plat_judge_1.0        0.00
# 53    new_bt_sgpt_judge_0.0        0.00
# 46     new_bt_mvc_judge_1.0        0.00
# 51     new_bt_wbc_judge_0.0        0.00
# 45     new_bt_mvc_judge_0.0        0.00
# 44    new_bt_mchc_judge_1.0        0.00
# 52     new_bt_wbc_judge_1.0        0.00
# 42     new_bt_mch_judge_1.0        0.00
# 47    new_bt_plat_judge_0.0        0.00
# 27           new_bp_judge_0        0.00
# 39     new_bt_hct_judge_0.0        0.00
# 38    new_bt_hbsa_judge_1.0        0.00
# 37    new_bt_hbsa_judge_0.0        0.00
# 36      new_bt_hb_judge_1.0        0.00
# 35      new_bt_hb_judge_0.0        0.00
# 34    new_bt_gluc_judge_1.0        0.00
# 31    new_bt_chol_judge_0.0        0.00
# 30  new_pulse_count_judge_1        0.00
# 29  new_pulse_count_judge_0        0.00
# 28           new_bp_judge_1        0.00
# 25         bt_hbsa_NEGATIVE        0.00
# 24                 gender_2        0.00
# 23                 gender_1        0.00
# 22          review_cat_혈액검사        0.00
# 54    new_bt_sgpt_judge_1.0        0.00

# %%
# 설명변수 중요도 그래프
# 중요도가 높은 변수를 상위에 그림
df_importance.sort_values("Importance", ascending=True, inplace=True)
coordinates=range(len(df_importance))
plt.barh(y=coordinates, width=df_importance["Importance"])
plt.yticks(coordinates, df_importance["Feature"])
plt.xlabel("설명변수 중요도")
plt.ylabel("설명변수")
# Out:
# Text(0, 0.5, '설명변수')
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54792 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54792 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 그래디언트 부스팅

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb_uncustomized=GradientBoostingClassifier(random_state=1234)
gb_uncustomized.fit(df_train_x, df_train_y)
# train 데이터셋 정확도
print("Accuracy on training set:{:.3f}".format(gb_uncustomized.score(df_train_x, df_train_y)))
# Validation 데이터 설명력
print("Accuracy on validation set:{:.3f}".format(gb_uncustomized.score(df_val_x, df_val_y)))
# Out:
# Accuracy on training set:0.919
# Accuracy on validation set:0.864

# %%
# train / test 정확도 결과 저장
train_accuracy=[]
val_accuracy=[]
# learning rate 변경 : 0.1~0.9
para_lr=[lr*0.05 for lr in range(1,10)]
for v_learning_rate in para_lr:
    gb=GradientBoostingClassifier(learning_rate=v_learning_rate, 
                                 random_state=1234)
    gb.fit(df_train_x, df_train_y)
    train_accuracy.append(gb.score(df_train_x, df_train_y))
    val_accuracy.append(gb.score(df_val_x, df_val_y))
# 테이블로 저장
df_accuracy_lr=pd.DataFrame()
df_accuracy_lr["LearningRate"]=para_lr
df_accuracy_lr["TrainAccuracy"]=train_accuracy
df_accuracy_lr["ValidationAccuracy"]=val_accuracy

# %%
# learning rate 별 정확도 테이블
df_accuracy_lr.round(3)
# Out:
#    LearningRate  TrainAccuracy  ValidationAccuracy
# 0          0.05          0.881               0.874
# 1          0.10          0.919               0.864
# 2          0.15          0.950               0.856
# 3          0.20          0.978               0.843
# 4          0.25          0.987               0.851
# 5          0.30          0.996               0.849
# 6          0.35          0.997               0.837
# 7          0.40          1.000               0.839
# 8          0.45          1.000               0.836

# %%
# Learning rate별 정확도 그래프로 확인
plt.plot(para_lr, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_lr, val_accuracy, linestyle="--", label="Validation Accuracy")
plt.ylabel("accuracy")
plt.xlabel("learning rate")
plt.legend()

# %%
# train / test 정확도 결과 저장
train_accuracy=[]
val_accuracy=[]
# n_estimators : 트리수 변경 10~150
para_n_tree=[n_tree*10 for n_tree in range(1,16)]
for v_n_estimators in para_n_tree:
    gb=GradientBoostingClassifier(n_estimators=v_n_estimators,
                                  learning_rate=0.05,
                                 random_state=1234)
    gb.fit(df_train_x, df_train_y)
    train_accuracy.append(gb.score(df_train_x, df_train_y))
    val_accuracy.append(gb.score(df_val_x, df_val_y))
# 테이블로 저장
df_accuracy_n=pd.DataFrame()
df_accuracy_n["Estimators"]=para_n_tree
df_accuracy_n["TrainAccuracy"]=train_accuracy
df_accuracy_n["ValidationAccuracy"]=val_accuracy

# %%
# n_estimators별 정확도
df_accuracy_n.round(3)
# Out:
#     Estimators  TrainAccuracy  ValidationAccuracy
# 0           10          0.864               0.885
# 1           20          0.864               0.885
# 2           30          0.864               0.883
# 3           40          0.865               0.881
# 4           50          0.867               0.879
# 5           60          0.872               0.877
# 6           70          0.874               0.877
# 7           80          0.877               0.875
# 8           90          0.880               0.875
# 9          100          0.881               0.874
# 10         110          0.888               0.874
# 11         120          0.889               0.874
# 12         130          0.892               0.875
# 13         140          0.894               0.874
# 14         150          0.897               0.872

# %%
# Learning rate별 정확도 그래프로 확인
plt.plot(para_n_tree, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_n_tree, val_accuracy, linestyle="--", label="Validation Accuracy")
plt.ylabel("accuracy")
plt.xlabel("learning rate")
plt.legend()

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
val_accuracy= []

# max_depth : 최대 깊이 변경
para_depth=[depth for depth in range(1,11)]

for v_max_depth in para_depth:
    gb=GradientBoostingClassifier(max_depth=v_max_depth,
                                n_estimators=120,
                                learning_rate=0.05,
                                random_state=1234)
    gb.fit(df_train_x, df_train_y)
    train_accuracy.append(gb.score(df_train_x, df_train_y))
    val_accuracy.append(gb.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_depth = pd.DataFrame()
df_accuracy_depth["Depth"]=para_depth
df_accuracy_depth["TrainAccuracy"]=train_accuracy
df_accuracy_depth["ValidationAccuracy"]=val_accuracy

# %%
# max_depth별 정확도 테이블
df_accuracy_depth.round(3)
# Out:
#    Depth  TrainAccuracy  ValidationAccuracy
# 0      1          0.864               0.885
# 1      2          0.868               0.878
# 2      3          0.889               0.874
# 3      4          0.928               0.871
# 4      5          0.973               0.871
# 5      6          0.999               0.862
# 6      7          1.000               0.866
# 7      8          1.000               0.868
# 8      9          1.000               0.872
# 9     10          1.000               0.877

# %%
# 모델 정확도 그래프 확인
plt.plot(para_depth, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_depth, val_accuracy, linestyle="--", label="Validation Accuracy")
plt.ylabel("accuacy")
plt.xlabel("depth")
plt.legend()

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
val_accuracy= []

# min_samples_split : 분할하기 위한 노드의 최소 샘플 수
para_split=[n_split*10 for n_split in range(2,11)]

for v_min_samples_split in para_split:
    gb=GradientBoostingClassifier(min_samples_split=v_min_samples_split
                                  ,max_depth=4,
                                n_estimators=120,
                                learning_rate=0.05,
                                random_state=1234)
    gb.fit(df_train_x, df_train_y)
    train_accuracy.append(gb.score(df_train_x, df_train_y))
    val_accuracy.append(gb.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_split = pd.DataFrame()
df_accuracy_split["MinSamplesSplit"]=para_split
df_accuracy_split["TrainAccuracy"]=train_accuracy
df_accuracy_split["ValidationAccuracy"]=val_accuracy

# %%
# min_samples_split 정확도 테이블
df_accuracy_split.round(3)
# Out:
#    MinSamplesSplit  TrainAccuracy  ValidationAccuracy
# 0               20          0.912               0.868
# 1               30          0.907               0.870
# 2               40          0.905               0.868
# 3               50          0.901               0.871
# 4               60          0.899               0.871
# 5               70          0.898               0.874
# 6               80          0.894               0.868
# 7               90          0.891               0.871
# 8              100          0.888               0.870

# %%
# 모델 정확도 그래프 확인
plt.plot(para_split, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_split, val_accuracy, linestyle="--", label="Validation Accuracy")
plt.ylabel("accuacy")
plt.xlabel("min samples split")
plt.legend()

# %%
# train 및 test 정확도 결과 저장
train_accuracy = []
val_accuracy= []

# min_samples_leaf :잎사귀 노드 최소 자료수 제한
para_leaf=[n_leaf*10 for n_leaf in range(1,11)]

for v_min_samples_leaf in para_leaf:
    gb=GradientBoostingClassifier(min_samples_leaf=v_min_samples_leaf
        ,min_samples_split=50
                                  ,max_depth=4,
                                n_estimators=120,
                                learning_rate=0.05,
                                random_state=1234)
    gb.fit(df_train_x, df_train_y)
    train_accuracy.append(gb.score(df_train_x, df_train_y))
    val_accuracy.append(gb.score(df_val_x, df_val_y))

# 결과 저장
df_accuracy_leaf = pd.DataFrame()
df_accuracy_leaf["MinSamplesLeaf"]=para_leaf
df_accuracy_leaf["TrainAccuracy"]=train_accuracy
df_accuracy_leaf["ValidationAccuracy"]=val_accuracy

# %%
df_accuracy_leaf.round(3)
# Out:
#    MinSamplesLeaf  TrainAccuracy  ValidationAccuracy
# 0              10          0.898               0.878
# 1              20          0.897               0.882
# 2              30          0.895               0.881
# 3              40          0.880               0.879
# 4              50          0.876               0.879
# 5              60          0.876               0.881
# 6              70          0.876               0.881
# 7              80          0.870               0.883
# 8              90          0.871               0.885
# 9             100          0.869               0.882

# %%
# 모델 정확도 그래프 확인
plt.plot(para_leaf, train_accuracy, linestyle="-", label="Train Accuracy")
plt.plot(para_leaf, val_accuracy, linestyle="--", label="Validation Accuracy")
plt.ylabel("accuacy")
plt.xlabel("min samples leaf")
plt.legend()

# %%
# 최종 모델
gb_final=GradientBoostingClassifier(min_samples_leaf=40,
                                   max_depth=4,
                                   n_estimators=120,
                                   learning_rate=0.05,
                                   random_state=1234)
gb_final.fit(df_train_x, df_train_y)

# 예측
y_pred=gb_final.predict(df_test_x)

# Train 데이터 정확도 / Test 데이터 정확도
print("Accuracy on training set:{:.3f}".format(gb_final.score(df_train_x, df_train_y)))
print("Accuracy on Test set:{:.3f}".format(gb_final.score(df_test_x, df_test_y)))

# confusion matrix
print("Confusion matrix:\n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy on training set:0.880
# Accuracy on Test set:0.864
# Confusion matrix:
# [[636   1]
#  [ 99   1]]

# %%
# feature_importances_ : 설명변수 중요도
v_feature_name=df_train_x.columns
# tree.feature_importances_로 설명변수 중요도 확인 및 테이블로 저장
df_importance=pd.DataFrame()
df_importance["Feature"]=v_feature_name
df_importance["Importance"]=gb_final.feature_importances_
# df_feature_importance의 테이블을 중요도 순으로 정렬
df_importance.sort_values("Importance", ascending=False, inplace=True)
df_importance.round(3)
# Out:
#                     Feature  Importance
# 10                  bt_chol       0.128
# 17                  bt_plat       0.100
# 0                       age       0.078
# 20                  bt_sgpt       0.072
# 12                    bt_hb       0.072
# 13                   bt_hct       0.063
# 2                    weight       0.056
# 5                       bmi       0.049
# 11                  bt_gluc       0.043
# 6                      whtr       0.042
# 18                   bt_rbc       0.039
# 19                   bt_wbc       0.039
# 7                    bp_min       0.035
# 16                   bt_mvc       0.034
# 15                  bt_mchc       0.030
# 9               pulse_count       0.028
# 1                    height       0.025
# 21          new_judge_score       0.014
# 3                      bust       0.013
# 8                    bp_max       0.010
# 4                     waist       0.010
# 39     new_bt_hct_judge_0.0       0.009
# 40     new_bt_hct_judge_1.0       0.006
# 14                   bt_mch       0.004
# 53    new_bt_sgpt_judge_0.0       0.000
# 52     new_bt_wbc_judge_1.0       0.000
# 51     new_bt_wbc_judge_0.0       0.000
# 38    new_bt_hbsa_judge_1.0       0.000
# 49     new_bt_rbc_judge_0.0       0.000
# 48    new_bt_plat_judge_1.0       0.000
# 47    new_bt_plat_judge_0.0       0.000
# 46     new_bt_mvc_judge_1.0       0.000
# 45     new_bt_mvc_judge_0.0       0.000
# 44    new_bt_mchc_judge_1.0       0.000
# 43    new_bt_mchc_judge_0.0       0.000
# 42     new_bt_mch_judge_1.0       0.000
# 41     new_bt_mch_judge_0.0       0.000
# 50     new_bt_rbc_judge_1.0       0.000
# 27           new_bp_judge_0       0.000
# 37    new_bt_hbsa_judge_0.0       0.000
# 36      new_bt_hb_judge_1.0       0.000
# 35      new_bt_hb_judge_0.0       0.000
# 34    new_bt_gluc_judge_1.0       0.000
# 33    new_bt_gluc_judge_0.0       0.000
# 32    new_bt_chol_judge_1.0       0.000
# 31    new_bt_chol_judge_0.0       0.000
# 30  new_pulse_count_judge_1       0.000
# 29  new_pulse_count_judge_0       0.000
# 28           new_bp_judge_1       0.000
# 26         bt_hbsa_POSITIVE       0.000
# 25         bt_hbsa_NEGATIVE       0.000
# 24                 gender_2       0.000
# 23                 gender_1       0.000
# 22          review_cat_혈액검사       0.000
# 54    new_bt_sgpt_judge_1.0       0.000

# %%
# 설명변수 중요도 그래프
# 중요도가 높은 변수를 상위에 그림
df_importance.sort_values("Importance", ascending=True, inplace=True)
coordinates=range(len(df_importance))
plt.barh(y=coordinates, width=df_importance["Importance"])
plt.yticks(coordinates, df_importance["Feature"])
plt.xlabel("설명변수 중요도")
plt.ylabel("설명변수")
# Out:
# Text(0, 0.5, '설명변수')
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54792 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54792 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# feature_importances_ : 설명변수 중요도
v_feature_name=df_train_x.columns
# tree.feature_importances_로 설명변수 중요도 확인 및 테이블로 저장
df_importance=pd.DataFrame()
df_importance["Feature"]=v_feature_name
df_importance["Importance"]=gb_final.feature_importances_
# df_feature_importance의 테이블을 중요도 순으로 정렬
df_importance.sort_values("Importance", ascending=False, inplace=True)
df_importance.round(3)
# Out:
#                     Feature  Importance
# 10                  bt_chol       0.128
# 17                  bt_plat       0.100
# 0                       age       0.078
# 20                  bt_sgpt       0.072
# 12                    bt_hb       0.072
# 13                   bt_hct       0.063
# 2                    weight       0.056
# 5                       bmi       0.049
# 11                  bt_gluc       0.043
# 6                      whtr       0.042
# 18                   bt_rbc       0.039
# 19                   bt_wbc       0.039
# 7                    bp_min       0.035
# 16                   bt_mvc       0.034
# 15                  bt_mchc       0.030
# 9               pulse_count       0.028
# 1                    height       0.025
# 21          new_judge_score       0.014
# 3                      bust       0.013
# 8                    bp_max       0.010
# 4                     waist       0.010
# 39     new_bt_hct_judge_0.0       0.009
# 40     new_bt_hct_judge_1.0       0.006
# 14                   bt_mch       0.004
# 53    new_bt_sgpt_judge_0.0       0.000
# 52     new_bt_wbc_judge_1.0       0.000
# 51     new_bt_wbc_judge_0.0       0.000
# 38    new_bt_hbsa_judge_1.0       0.000
# 49     new_bt_rbc_judge_0.0       0.000
# 48    new_bt_plat_judge_1.0       0.000
# 47    new_bt_plat_judge_0.0       0.000
# 46     new_bt_mvc_judge_1.0       0.000
# 45     new_bt_mvc_judge_0.0       0.000
# 44    new_bt_mchc_judge_1.0       0.000
# 43    new_bt_mchc_judge_0.0       0.000
# 42     new_bt_mch_judge_1.0       0.000
# 41     new_bt_mch_judge_0.0       0.000
# 50     new_bt_rbc_judge_1.0       0.000
# 27           new_bp_judge_0       0.000
# 37    new_bt_hbsa_judge_0.0       0.000
# 36      new_bt_hb_judge_1.0       0.000
# 35      new_bt_hb_judge_0.0       0.000
# 34    new_bt_gluc_judge_1.0       0.000
# 33    new_bt_gluc_judge_0.0       0.000
# 32    new_bt_chol_judge_1.0       0.000
# 31    new_bt_chol_judge_0.0       0.000
# 30  new_pulse_count_judge_1       0.000
# 29  new_pulse_count_judge_0       0.000
# 28           new_bp_judge_1       0.000
# 26         bt_hbsa_POSITIVE       0.000
# 25         bt_hbsa_NEGATIVE       0.000
# 24                 gender_2       0.000
# 23                 gender_1       0.000
# 22          review_cat_혈액검사       0.000
# 54    new_bt_sgpt_judge_1.0       0.000

# %%
# 설명변수 중요도 그래프
# 중요도가 높은 변수를 상위에 그림
df_importance.sort_values("Importance", ascending=True, inplace=True)
coordinates=range(len(df_importance))
plt.barh(y=coordinates, width=df_importance["Importance"])
plt.yticks(coordinates, df_importance["Feature"])
plt.xlabel("설명변수 중요도")
plt.ylabel("설명변수")
# Out:
# Text(0, 0.5, '설명변수')
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54792 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54792 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44160 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jykan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 거절 고객 분류

# %%
test_data = pd.read_csv("new_insu_pre_review.csv", engine="python")

# %%
rejection = test_data[test_data['judge']=='거절']

# %%
rejection
# Out:
#       customer_id review_cat judge review_date  gender  age  height  weight  \
# 4         C112358       혈액검사    거절  2015-02-24       1   70     166      73
# 12        C112374       혈액검사    거절  2015-01-22       1   70     175      66
# 37        C112409       일반검진    거절  2015-01-20       1   69     178      75
# 40        C112414       일반검진    거절  2014-10-13       1   68     165      70
# 44        C112421       일반검진    거절  2015-08-02       1   69     165      55
# ...           ...        ...   ...         ...     ...  ...     ...     ...
# 14908     C134201       혈액검사    거절  2015-02-16       1   48     160      58
# 14909     C134203       혈액검사    거절  2015-09-07       1   51     165      65
# 14910     C134204       혈액검사    거절  2015-03-10       1   54     180      83
# 14929     C134237       혈액검사    거절  2014-10-30       2   53     158      62
# 14931     C134240       일반검진    거절  2015-08-27       2   22     160      47
#
#        bust  waist  ...  new_bt_mch_judge  new_bt_mchc_judge  \
# 4       100     91  ...               NaN                NaN
# 12       98     84  ...               NaN                NaN
# 37       99     90  ...               NaN                NaN
# 40       94     88  ...               NaN                NaN
# 44       93     82  ...               NaN                NaN
# ...     ...    ...  ...               ...                ...
# 14908    91     74  ...               NaN                NaN
# 14909    98     87  ...               0.0                0.0
# 14910    95     86  ...               NaN                NaN
# 14929    90     80  ...               0.0                0.0
# 14931    80     60  ...               NaN                NaN
#
#        new_bt_mvc_judge  new_bt_plat_judge  new_bt_rbc_judge  \
# 4                   NaN                NaN               NaN
# 12                  NaN                NaN               NaN
# 37                  NaN                NaN               NaN
# 40                  NaN                NaN               NaN
# 44                  NaN                NaN               NaN
# ...                 ...                ...               ...
# 14908               NaN                NaN               NaN
# 14909               0.0                0.0               1.0
# 14910               NaN                NaN               NaN
# 14929               0.0                0.0               0.0
# 14931               NaN                NaN               NaN
#
#        new_bt_wbc_judge  new_bt_rgpt_judge  new_bt_sgot_judge  \
# 4                   NaN                0.0                0.0
# 12                  NaN                0.0                0.0
# 37                  NaN                NaN                NaN
# 40                  NaN                NaN                NaN
# 44                  NaN                NaN                NaN
# ...                 ...                ...                ...
# 14908               NaN                0.0                0.0
# 14909               0.0                1.0                0.0
# 14910               NaN                0.0                0.0
# 14929               0.0                NaN                NaN
# 14931               NaN                NaN                NaN
#
#        new_bt_sgpt_judge new_bt_trig_judge
# 4                    1.0               NaN
# 12                   0.0               NaN
# 37                   NaN               NaN
# 40                   NaN               NaN
# 44                   NaN               NaN
# ...                  ...               ...
# 14908                0.0               NaN
# 14909                0.0               1.0
# 14910                0.0               NaN
# 14929                0.0               NaN
# 14931                NaN               NaN
#
# [2827 rows x 50 columns]

# %%
blood_rejection = rejection[rejection['review_cat']=='혈액검사']
blood_rejection
# Out:
#       customer_id review_cat judge review_date  gender  age  height  weight  \
# 4         C112358       혈액검사    거절  2015-02-24       1   70     166      73
# 12        C112374       혈액검사    거절  2015-01-22       1   70     175      66
# 49        C112426       혈액검사    거절  2014-10-16       1   68     170      72
# 50        C112427       혈액검사    거절  2015-03-19       1   68     169      57
# 53        C112431       혈액검사    거절  2015-04-14       1   68     165      70
# ...           ...        ...   ...         ...     ...  ...     ...     ...
# 14906     C134198       혈액검사    거절  2015-09-13       1   44     174      75
# 14908     C134201       혈액검사    거절  2015-02-16       1   48     160      58
# 14909     C134203       혈액검사    거절  2015-09-07       1   51     165      65
# 14910     C134204       혈액검사    거절  2015-03-10       1   54     180      83
# 14929     C134237       혈액검사    거절  2014-10-30       2   53     158      62
#
#        bust  waist  ...  new_bt_mch_judge  new_bt_mchc_judge  \
# 4       100     91  ...               NaN                NaN
# 12       98     84  ...               NaN                NaN
# 49       96     90  ...               NaN                NaN
# 50       97     81  ...               NaN                NaN
# 53       97     89  ...               0.0                0.0
# ...     ...    ...  ...               ...                ...
# 14906    97     86  ...               0.0                0.0
# 14908    91     74  ...               NaN                NaN
# 14909    98     87  ...               0.0                0.0
# 14910    95     86  ...               NaN                NaN
# 14929    90     80  ...               0.0                0.0
#
#        new_bt_mvc_judge  new_bt_plat_judge  new_bt_rbc_judge  \
# 4                   NaN                NaN               NaN
# 12                  NaN                NaN               NaN
# 49                  NaN                NaN               NaN
# 50                  NaN                NaN               NaN
# 53                  0.0                0.0               0.0
# ...                 ...                ...               ...
# 14906               0.0                0.0               0.0
# 14908               NaN                NaN               NaN
# 14909               0.0                0.0               1.0
# 14910               NaN                NaN               NaN
# 14929               0.0                0.0               0.0
#
#        new_bt_wbc_judge  new_bt_rgpt_judge  new_bt_sgot_judge  \
# 4                   NaN                0.0                0.0
# 12                  NaN                0.0                0.0
# 49                  NaN                0.0                0.0
# 50                  NaN                0.0                0.0
# 53                  0.0                1.0                1.0
# ...                 ...                ...                ...
# 14906               0.0                0.0                0.0
# 14908               NaN                0.0                0.0
# 14909               0.0                1.0                0.0
# 14910               NaN                0.0                0.0
# 14929               0.0                NaN                NaN
#
#        new_bt_sgpt_judge new_bt_trig_judge
# 4                    1.0               NaN
# 12                   0.0               NaN
# 49                   0.0               1.0
# 50                   0.0               NaN
# 53                   1.0               0.0
# ...                  ...               ...
# 14906                1.0               1.0
# 14908                0.0               NaN
# 14909                0.0               1.0
# 14910                0.0               NaN
# 14929                0.0               NaN
#
# [2344 rows x 50 columns]

# %%
hook = blood_rejection.drop(['bt_crea','bt_rgpt','bt_sgot','bt_trig','new_bt_crea_judge','new_bt_rgpt_judge',
                'new_bt_sgot_judge','new_bt_trig_judge',
                            'customer_id','review_date','judge'], axis=1)

# %%
hap = hook.dropna(subset=['bt_hb'])
new = hap

# %%
new['gender'] = new['gender'].astype('object')
new['new_bp_judge'] = new['new_bp_judge'].astype('object')
new['new_pulse_count_judge'] = new['new_pulse_count_judge'].astype('object')
new['new_bt_chol_judge'] = new['new_bt_chol_judge'].astype('object')
new['new_bt_gluc_judge'] = new['new_bt_gluc_judge'].astype('object')
new['new_bt_hb_judge'] = new['new_bt_hb_judge'].astype('object')
new['new_bt_hbsa_judge'] = new['new_bt_hbsa_judge'].astype('object')
new['new_bt_hct_judge'] = new['new_bt_hct_judge'].astype('object')
new['new_bt_mch_judge'] = new['new_bt_mch_judge'].astype('object')
new['new_bt_mchc_judge'] = new['new_bt_mchc_judge'].astype('object')
new['new_bt_mvc_judge'] = new['new_bt_mvc_judge'].astype('object')
new['new_bt_plat_judge'] = new['new_bt_plat_judge'].astype('object')
new['new_bt_rbc_judge'] = new['new_bt_rbc_judge'].astype('object')
new['new_bt_wbc_judge'] = new['new_bt_wbc_judge'].astype('object')
new['new_bt_sgpt_judge'] = new['new_bt_sgpt_judge'].astype('object')
# Out:
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jykan\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
happ = pd.get_dummies(new)
happ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1519 entries, 53 to 14929
# Data columns (total 55 columns):
# age                        1519 non-null int64
# height                     1519 non-null int64
# weight                     1519 non-null int64
# bust                       1519 non-null int64
# waist                      1519 non-null int64
# bmi                        1519 non-null float64
# whtr                       1519 non-null float64
# bp_min                     1519 non-null int64
# bp_max                     1519 non-null int64
# pulse_count                1519 non-null int64
# bt_chol                    1519 non-null float64
# bt_gluc                    1519 non-null float64
# bt_hb                      1519 non-null float64
# bt_hct                     1519 non-null float64
# bt_mch                     1519 non-null float64
# bt_mchc                    1519 non-null float64
# bt_mvc                     1519 non-null float64
# bt_plat                    1519 non-null float64
# bt_rbc                     1519 non-null float64
# bt_wbc                     1519 non-null float64
# bt_sgpt                    1519 non-null float64
# new_judge_score            1519 non-null int64
# review_cat_혈액검사            1519 non-null uint8
# gender_1                   1519 non-null uint8
# gender_2                   1519 non-null uint8
# bt_hbsa_NEGATIVE           1519 non-null uint8
# bt_hbsa_POSITIVE           1519 non-null uint8
# new_bp_judge_0             1519 non-null uint8
# new_bp_judge_1             1519 non-null uint8
# new_pulse_count_judge_0    1519 non-null uint8
# new_pulse_count_judge_1    1519 non-null uint8
# new_bt_chol_judge_0.0      1519 non-null uint8
# new_bt_chol_judge_1.0      1519 non-null uint8
# new_bt_gluc_judge_0.0      1519 non-null uint8
# new_bt_gluc_judge_1.0      1519 non-null uint8
# new_bt_hb_judge_0.0        1519 non-null uint8
# new_bt_hb_judge_1.0        1519 non-null uint8
# new_bt_hbsa_judge_0.0      1519 non-null uint8
# new_bt_hbsa_judge_1.0      1519 non-null uint8
# new_bt_hct_judge_0.0       1519 non-null uint8
# new_bt_hct_judge_1.0       1519 non-null uint8
# new_bt_mch_judge_0.0       1519 non-null uint8
# new_bt_mch_judge_1.0       1519 non-null uint8
# new_bt_mchc_judge_0.0      1519 non-null uint8
# new_bt_mchc_judge_1.0      1519 non-null uint8
# new_bt_mvc_judge_0.0       1519 non-null uint8
# new_bt_mvc_judge_1.0       1519 non-null uint8
# new_bt_plat_judge_0.0      1519 non-null uint8
# new_bt_plat_judge_1.0      1519 non-null uint8
# new_bt_rbc_judge_0.0       1519 non-null uint8
# new_bt_rbc_judge_1.0       1519 non-null uint8
# new_bt_wbc_judge_0.0       1519 non-null uint8
# new_bt_wbc_judge_1.0       1519 non-null uint8
# new_bt_sgpt_judge_0.0      1519 non-null uint8
# new_bt_sgpt_judge_1.0      1519 non-null uint8
# dtypes: float64(13), int64(9), uint8(33)
# memory usage: 321.9 KB

# %%
df_end.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 8 to 4491
# Data columns (total 58 columns):
# age                        2456 non-null int64
# height                     2456 non-null int64
# weight                     2456 non-null int64
# bust                       2456 non-null int64
# waist                      2456 non-null int64
# bmi                        2456 non-null float64
# whtr                       2456 non-null float64
# bp_min                     2456 non-null int64
# bp_max                     2456 non-null int64
# pulse_count                2456 non-null int64
# bt_chol                    2456 non-null float64
# bt_gluc                    2456 non-null float64
# bt_hb                      2456 non-null float64
# bt_hct                     2456 non-null float64
# bt_mch                     2456 non-null float64
# bt_mchc                    2456 non-null float64
# bt_mvc                     2456 non-null float64
# bt_plat                    2456 non-null float64
# bt_rbc                     2456 non-null float64
# bt_wbc                     2456 non-null float64
# bt_sgpt                    2456 non-null float64
# new_judge_score            2456 non-null int64
# risk                       2456 non-null int64
# review_cat_혈액검사            2456 non-null uint8
# judge_승인                   2456 non-null uint8
# judge_재검                   2456 non-null uint8
# gender_1                   2456 non-null uint8
# gender_2                   2456 non-null uint8
# bt_hbsa_NEGATIVE           2456 non-null uint8
# bt_hbsa_POSITIVE           2456 non-null uint8
# new_bp_judge_0             2456 non-null uint8
# new_bp_judge_1             2456 non-null uint8
# new_pulse_count_judge_0    2456 non-null uint8
# new_pulse_count_judge_1    2456 non-null uint8
# new_bt_chol_judge_0.0      2456 non-null uint8
# new_bt_chol_judge_1.0      2456 non-null uint8
# new_bt_gluc_judge_0.0      2456 non-null uint8
# new_bt_gluc_judge_1.0      2456 non-null uint8
# new_bt_hb_judge_0.0        2456 non-null uint8
# new_bt_hb_judge_1.0        2456 non-null uint8
# new_bt_hbsa_judge_0.0      2456 non-null uint8
# new_bt_hbsa_judge_1.0      2456 non-null uint8
# new_bt_hct_judge_0.0       2456 non-null uint8
# new_bt_hct_judge_1.0       2456 non-null uint8
# new_bt_mch_judge_0.0       2456 non-null uint8
# new_bt_mch_judge_1.0       2456 non-null uint8
# new_bt_mchc_judge_0.0      2456 non-null uint8
# new_bt_mchc_judge_1.0      2456 non-null uint8
# new_bt_mvc_judge_0.0       2456 non-null uint8
# new_bt_mvc_judge_1.0       2456 non-null uint8
# new_bt_plat_judge_0.0      2456 non-null uint8
# new_bt_plat_judge_1.0      2456 non-null uint8
# new_bt_rbc_judge_0.0       2456 non-null uint8
# new_bt_rbc_judge_1.0       2456 non-null uint8
# new_bt_wbc_judge_0.0       2456 non-null uint8
# new_bt_wbc_judge_1.0       2456 non-null uint8
# new_bt_sgpt_judge_0.0      2456 non-null uint8
# new_bt_sgpt_judge_1.0      2456 non-null uint8
# dtypes: float64(13), int64(10), uint8(35)
# memory usage: 544.4 KB

# %%
y_pred=dt_tree_final.predict(happ)
print("Accuracy:{0:.3f}\n".format(dt_tree_final.score(df_test_x, df_test_y)))
# Out:
# Accuracy:0.864

# %%
happ['gb_pred'] = y_pred
happ.groupby('gb_pred').count()
# Out:
#           age  height  weight  bust  waist   bmi  whtr  bp_min  bp_max  \
# gb_pred
# 0        1519    1519    1519  1519   1519  1519  1519    1519    1519
#
#          pulse_count  ...  new_bt_mvc_judge_0.0  new_bt_mvc_judge_1.0  \
# gb_pred               ...
# 0               1519  ...                  1519                  1519
#
#          new_bt_plat_judge_0.0  new_bt_plat_judge_1.0  new_bt_rbc_judge_0.0  \
# gb_pred
# 0                         1519                   1519                  1519
#
#          new_bt_rbc_judge_1.0  new_bt_wbc_judge_0.0  new_bt_wbc_judge_1.0  \
# gb_pred
# 0                        1519                  1519                  1519
#
#          new_bt_sgpt_judge_0.0  new_bt_sgpt_judge_1.0
# gb_pred
# 0                         1519                   1519
#
# [1 rows x 55 columns]

# %%
happ = happ.drop(['gb_pred'],axis=1)

# %%
dt_y_pred=dt_tree_final.predict(happ)
print("Accuracy:{0:.3f}\n".format(dt_tree_final.score(df_test_x, df_test_y)))
# Out:
# Accuracy:0.864

# %%
happ['dt_pred'] = dt_y_pred
happ.groupby('dt_pred').count()
# Out:
#           age  height  weight  bust  waist   bmi  whtr  bp_min  bp_max  \
# dt_pred
# 0        1519    1519    1519  1519   1519  1519  1519    1519    1519
#
#          pulse_count  ...  new_bt_mvc_judge_0.0  new_bt_mvc_judge_1.0  \
# dt_pred               ...
# 0               1519  ...                  1519                  1519
#
#          new_bt_plat_judge_0.0  new_bt_plat_judge_1.0  new_bt_rbc_judge_0.0  \
# dt_pred
# 0                         1519                   1519                  1519
#
#          new_bt_rbc_judge_1.0  new_bt_wbc_judge_0.0  new_bt_wbc_judge_1.0  \
# dt_pred
# 0                        1519                  1519                  1519
#
#          new_bt_sgpt_judge_0.0  new_bt_sgpt_judge_1.0
# dt_pred
# 0                         1519                   1519
#
# [1 rows x 55 columns]

# %%
happ = happ.drop(['dt_pred'],axis=1)

# %%
rf_y_pred=rf_tree_final.predict(happ)
print("Accuracy:{0:.3f}\n".format(rf_tree_final.score(df_test_x, df_test_y)))
# Out:
# Accuracy:0.864

# %%
happ['rf_pred'] = rf_y_pred
happ.groupby('rf_pred').count()
# Out:
#           age  height  weight  bust  waist   bmi  whtr  bp_min  bp_max  \
# rf_pred
# 0        1519    1519    1519  1519   1519  1519  1519    1519    1519
#
#          pulse_count  ...  new_bt_mvc_judge_0.0  new_bt_mvc_judge_1.0  \
# rf_pred               ...
# 0               1519  ...                  1519                  1519
#
#          new_bt_plat_judge_0.0  new_bt_plat_judge_1.0  new_bt_rbc_judge_0.0  \
# rf_pred
# 0                         1519                   1519                  1519
#
#          new_bt_rbc_judge_1.0  new_bt_wbc_judge_0.0  new_bt_wbc_judge_1.0  \
# rf_pred
# 0                        1519                  1519                  1519
#
#          new_bt_sgpt_judge_0.0  new_bt_sgpt_judge_1.0
# rf_pred
# 0                         1519                   1519
#
# [1 rows x 55 columns]
